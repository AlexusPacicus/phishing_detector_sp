# %%
import pandas as pd

PATH = "../data/clean/dataset_base_v21.csv"  # ajusta si lo tienes en otra ruta
df = pd.read_csv(PATH)
df.shape
# Out:
# (492, 31)

# %%
df["label"].value_counts(dropna=False)
# Out:
# label
# 1    248
# 0    244
# Name: count, dtype: int64

# %%
df["source"].value_counts(dropna=False)
# Out:
# source
# NaN       342
# manual    150
# Name: count, dtype: int64

# %%
df["sector"].value_counts(dropna=False)
# Out:
# sector
# NaN                                192
# Banca                              133
# Logística                           91
# Genérico / Otros                    28
# Cripto / Fintech                    12
# Retail / e-commerce / Streaming     10
# Energía / Seguros                   10
# SaaS / Cloud / Plataformas          10
# Público / Administración             5
# Administración pública               1
# Name: count, dtype: int64

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df.columns.tolist()
# Out:
# ['campaign',
#  'categoria',
#  'confianza',
#  'confidence',
#  'dataset_split',
#  'domain',
#  'entidad',
#  'free_hosting',
#  'inclusion',
#  'is_https',
#  'label',
#  'matched_target',
#  'notas',
#  'route_type',
#  'ruido',
#  'score_total_v2',
#  'sector',
#  'sector_norm',
#  'source',
#  'timestamp',
#  'url',
#  'url_norm',
#  'domain_complexity',
#  'host_entropy',
#  'domain_whitelist_score',
#  'suspicious_path_token',
#  'token_density',
#  'trusted_token_context',
#  'infra_risk',
#  'fake_tld_in_subdomain_or_path',
#  'param_count_boost']

# %%
df.groupby("label")["sector"].value_counts(dropna=False)
# Out:
# label  sector
# 0      NaN                                94
#        Banca                              58
#        Logística                          35
#        Cripto / Fintech                   12
#        Energía / Seguros                  10
#        Genérico / Otros                   10
#        Retail / e-commerce / Streaming    10
#        SaaS / Cloud / Plataformas         10
#        Público / Administración            5
# 1      NaN                                98
#        Banca                              75
#        Logística                          56
#        Genérico / Otros                   18
#        Administración pública              1
# Name: count, dtype: int64

# %%
df[df["sector"].isna()][["url","domain","entidad","matched_target","categoria"]].head(20)
# Out:
#                                                    url domain entidad  \
# 0    https://www.caixabank.es/particular/banca-digi...    NaN     NaN
# 151  https://pasarela.clave.gob.es/Proxy2/ServicePr...    NaN     NaN
# 152  https://www.bancomediolanum.es/es-ES/la-banca-...    NaN     NaN
# 153         https://www.bancosantander.es/particulares    NaN     NaN
# 154    https://www.movistar.es/area-cliente/mi-cuenta/    NaN     NaN
# 155                   https://m.vodafone.es/mves/login    NaN     NaN
# 156              https://www.ing.es/seguridad-internet    NaN     NaN
# 157               https://www.openbank.es/app-openbank    NaN     NaN
# 158                                https://www.ing.es/    NaN     NaN
# 159   https://www.openbank.es/?toggleLogin&go-to-app=0    NaN     NaN
# 160                https://login.decathlon.net/sign-in    NaN     NaN
# 161                    https://www.amazon.es/ap/signin    NaN     NaN
# 162               https://www.hbomax.com/es/es/sign-in    NaN     NaN
# 163                https://www.orange.es/pago-facturas    NaN     NaN
# 164  https://www.bancosantander.es/particulares/ban...    NaN     NaN
# 165                 https://www.bbva.es/personas.html#    NaN     NaN
# 166                      https://www.correosexpress.es    NaN     NaN
# 167                      https://walletconnect.network    NaN     NaN
# 168        https://www.unicajabanco.es/es/particulares    NaN     NaN
# 169                          https://www.bmedonline.es    NaN     NaN
#
#      matched_target           categoria
# 0         caixabank               banca
# 151           cl@ve             público
# 152      mediolanum               banca
# 153       santander               banca
# 154        movistar  telecomunicaciones
# 155        vodafone  telecomunicaciones
# 156             ing               banca
# 157        openbank               banca
# 158             ing               banca
# 159        openbank               banca
# 160       decathlon          e-commerce
# 161          amazon          e-commerce
# 162             hbo           streaming
# 163          orange  telecomunicaciones
# 164       santander               banca
# 165            bbva               banca
# 166  correosexpress           logística
# 167   walletconnect              cripto
# 168    unicajabanco               banca
# 169      mediolanum               banca

# %%
import re

# Guardamos una muestra de filas con sector nulo para validar
nan_subset = df[df["sector"].isna()][["url", "domain", "entidad", "matched_target", "categoria", "sector"]].head(20)
nan_indices = nan_subset.index

filled_by_rule = {
    "regla_1_matched_target": 0,
    "regla_2_categoria": 0,
    "regla_3_tokens": 0,
    "regla_4_default": 0,
}

# Regla 1: matched_target -> sector
matched_sector_map = {
    "caixabank": "Banca",
    "mediolanum": "Banca",
    "santander": "Banca",
    "ing": "Banca",
    "openbank": "Banca",
    "bbva": "Banca",
    "unicajabanco": "Banca",
    "movistar": "Telecomunicaciones",
    "vodafone": "Telecomunicaciones",
    "orange": "Telecomunicaciones",
    "correos": "Logística",
    "correosexpress": "Logística",
    "walletconnect": "Cripto / Fintech",
    "decathlon": "Retail / e-commerce / Streaming",
    "amazon": "Retail / e-commerce / Streaming",
    "hbo": "Retail / e-commerce / Streaming",
    "clave": "Público / Administración",
    "cl@ve": "Público / Administración",
}
matched_lower = df["matched_target"].astype(str).str.lower().str.strip()
mask_rule1 = df["sector"].isna() & matched_lower.map(matched_sector_map).notna()
filled_by_rule["regla_1_matched_target"] = int(mask_rule1.sum())
df.loc[mask_rule1, "sector"] = matched_lower.map(matched_sector_map)

# Regla 2: categoria -> sector
categoria_sector_map = {
    "banca": "Banca",
    "telecomunicaciones": "Telecomunicaciones",
    "logística": "Logística",
    "logistica": "Logística",
    "e-commerce": "Retail / e-commerce / Streaming",
    "streaming": "Retail / e-commerce / Streaming",
    "público": "Público / Administración",
    "publico": "Público / Administración",
}
categoria_lower = df["categoria"].astype(str).str.lower().str.strip()
mask_rule2 = df["sector"].isna() & categoria_lower.map(categoria_sector_map).notna()
filled_by_rule["regla_2_categoria"] = int(mask_rule2.sum())
df.loc[mask_rule2, "sector"] = categoria_lower.map(categoria_sector_map)

# Regla 3: tokens en URL/domain -> sector
sector_tokens = [
    ("Banca", ["bbva", "santander", "caixabank", "ing", "openbank", "unicaja"]),
    ("Logística", ["correos", "seur", "mrw", "correosexpress"]),
    ("Telecomunicaciones", ["movistar", "vodafone", "orange", "o2"]),
    ("Cripto / Fintech", ["crypto", "wallet", "metamask"]),
    ("Retail / e-commerce / Streaming", ["amazon", "ikea", "zalando", "decathlon"]),
    ("Retail / e-commerce / Streaming", ["hbo", "netflix"]),
]
for sector_value, tokens in sector_tokens:
    token_pattern = "|".join(re.escape(t) for t in tokens)
    token_hits = df["url"].str.contains(token_pattern, case=False, na=False) | df["domain"].str.contains(token_pattern, case=False, na=False)
    mask_rule3 = df["sector"].isna() & token_hits
    count_rule3 = int(mask_rule3.sum())
    if count_rule3:
        df.loc[mask_rule3, "sector"] = sector_value
        filled_by_rule["regla_3_tokens"] += count_rule3

# Regla 4: sin coincidencia -> Genérico / Otros
mask_rule4 = df["sector"].isna()
filled_by_rule["regla_4_default"] = int(mask_rule4.sum())
df.loc[mask_rule4, "sector"] = "Genérico / Otros"

print("Filas rellenadas por regla:")
for regla, cantidad in filled_by_rule.items():
    print(f"- {regla}: {cantidad}")

after_subset = df.loc[nan_indices, ["url", "domain", "entidad", "matched_target", "categoria", "sector"]]
print("\nAntes (sector NaN):")
display(nan_subset)
print("Después de aplicar reglas:")
display(after_subset)
# Out:
# Filas rellenadas por regla:
# - regla_1_matched_target: 64
# - regla_2_categoria: 68
# - regla_3_tokens: 2
# - regla_4_default: 58
#
# Antes (sector NaN):
#                                                    url domain entidad  \
# 0    https://www.caixabank.es/particular/banca-digi...    NaN     NaN
# 151  https://pasarela.clave.gob.es/Proxy2/ServicePr...    NaN     NaN
# 152  https://www.bancomediolanum.es/es-ES/la-banca-...    NaN     NaN
# 153         https://www.bancosantander.es/particulares    NaN     NaN
# 154    https://www.movistar.es/area-cliente/mi-cuenta/    NaN     NaN
# 155                   https://m.vodafone.es/mves/login    NaN     NaN
# 156              https://www.ing.es/seguridad-internet    NaN     NaN
# 157               https://www.openbank.es/app-openbank    NaN     NaN
# 158                                https://www.ing.es/    NaN     NaN
# 159   https://www.openbank.es/?toggleLogin&go-to-app=0    NaN     NaN
# 160                https://login.decathlon.net/sign-in    NaN     NaN
# 161                    https://www.amazon.es/ap/signin    NaN     NaN
# 162               https://www.hbomax.com/es/es/sign-in    NaN     NaN
# 163                https://www.orange.es/pago-facturas    NaN     NaN
# 164  https://www.bancosantander.es/particulares/ban...    NaN     NaN
# 165                 https://www.bbva.es/personas.html#    NaN     NaN
# 166                      https://www.correosexpress.es    NaN     NaN
# 167                      https://walletconnect.network    NaN     NaN
# 168        https://www.unicajabanco.es/es/particulares    NaN     NaN
# 169                          https://www.bmedonline.es    NaN     NaN
#
#      matched_target           categoria sector
# 0         caixabank               banca    NaN
# 151           cl@ve             público    NaN
# 152      mediolanum               banca    NaN
# 153       santander               banca    NaN
# 154        movistar  telecomunicaciones    NaN
# 155        vodafone  telecomunicaciones    NaN
# 156             ing               banca    NaN
# 157        openbank               banca    NaN
# 158             ing               banca    NaN
# 159        openbank               banca    NaN
# 160       decathlon          e-commerce    NaN
# 161          amazon          e-commerce    NaN
# 162             hbo           streaming    NaN
# 163          orange  telecomunicaciones    NaN
# 164       santander               banca    NaN
# 165            bbva               banca    NaN
# 166  correosexpress           logística    NaN
# 167   walletconnect              cripto    NaN
# 168    unicajabanco               banca    NaN
# 169      mediolanum               banca    NaN
# Después de aplicar reglas:
#                                                    url domain entidad  \
# 0    https://www.caixabank.es/particular/banca-digi...    NaN     NaN
# 151  https://pasarela.clave.gob.es/Proxy2/ServicePr...    NaN     NaN
# 152  https://www.bancomediolanum.es/es-ES/la-banca-...    NaN     NaN
# 153         https://www.bancosantander.es/particulares    NaN     NaN
# 154    https://www.movistar.es/area-cliente/mi-cuenta/    NaN     NaN
# 155                   https://m.vodafone.es/mves/login    NaN     NaN
# 156              https://www.ing.es/seguridad-internet    NaN     NaN
# 157               https://www.openbank.es/app-openbank    NaN     NaN
# 158                                https://www.ing.es/    NaN     NaN
# 159   https://www.openbank.es/?toggleLogin&go-to-app=0    NaN     NaN
# 160                https://login.decathlon.net/sign-in    NaN     NaN
# 161                    https://www.amazon.es/ap/signin    NaN     NaN
# 162               https://www.hbomax.com/es/es/sign-in    NaN     NaN
# 163                https://www.orange.es/pago-facturas    NaN     NaN
# 164  https://www.bancosantander.es/particulares/ban...    NaN     NaN
# 165                 https://www.bbva.es/personas.html#    NaN     NaN
# 166                      https://www.correosexpress.es    NaN     NaN
# 167                      https://walletconnect.network    NaN     NaN
# 168        https://www.unicajabanco.es/es/particulares    NaN     NaN
# 169                          https://www.bmedonline.es    NaN     NaN
#
#      matched_target           categoria                           sector
# 0         caixabank               banca                            Banca
# 151           cl@ve             público         Público / Administración
# 152      mediolanum               banca                            Banca
# 153       santander               banca                            Banca
# 154        movistar  telecomunicaciones               Telecomunicaciones
# 155        vodafone  telecomunicaciones               Telecomunicaciones
# 156             ing               banca                            Banca
# 157        openbank               banca                            Banca
# 158             ing               banca                            Banca
# 159        openbank               banca                            Banca
# 160       decathlon          e-commerce  Retail / e-commerce / Streaming
# 161          amazon          e-commerce  Retail / e-commerce / Streaming
# 162             hbo           streaming  Retail / e-commerce / Streaming
# 163          orange  telecomunicaciones               Telecomunicaciones
# 164       santander               banca                            Banca
# 165            bbva               banca                            Banca
# 166  correosexpress           logística                        Logística
# 167   walletconnect              cripto                 Cripto / Fintech
# 168    unicajabanco               banca                            Banca
# 169      mediolanum               banca                            Banca

# %%
# Filtrar filas con sector genérico
## df_gen contiene únicamente las filas donde sector es "Genérico / Otros"
df_gen = df[df["sector"] == "Genérico / Otros"].copy()
print(f"Filas en df_gen: {len(df_gen)}")
display(df_gen.head(20))
# Out:
# Filas en df_gen: 86
#     campaign categoria  confianza  confidence dataset_split domain  \
# 95       NaN       NaN        NaN        93.0           NaN    NaN
# 96       NaN       NaN        NaN        93.0           NaN    NaN
# 97       NaN       NaN        NaN        92.0           NaN    NaN
# 98       NaN       NaN        NaN        92.0           NaN    NaN
# 99       NaN       NaN        NaN        93.0           NaN    NaN
# 100      NaN       NaN        NaN        93.0           NaN    NaN
# 101      NaN       NaN        NaN        93.0           NaN    NaN
# 102      NaN       NaN        NaN        93.0           NaN    NaN
# 103      NaN       NaN        NaN        93.0           NaN    NaN
# 104      NaN       NaN        NaN        94.0           NaN    NaN
# 170      NaN    cripto        NaN         NaN           NaN    NaN
# 178      NaN      rrss        NaN         NaN           NaN    NaN
# 180      NaN    viajes        NaN         NaN           NaN    NaN
# 181      NaN    viajes        NaN         NaN           NaN    NaN
# 182      NaN   energía        NaN         NaN           NaN    NaN
# 183      NaN      saas        NaN         NaN           NaN    NaN
# 184      NaN      rrss        NaN         NaN           NaN    NaN
# 187      NaN   seguros        NaN         NaN           NaN    NaN
# 188      NaN   seguros        NaN         NaN           NaN    NaN
# 190      NaN   energía        NaN         NaN           NaN    NaN
#
#                  entidad  free_hosting  inclusion  is_https  ...  \
# 95               Twitter           0.0        NaN       1.0  ...
# 96              LinkedIn           0.0        NaN       1.0  ...
# 97                  Okta           0.0        NaN       1.0  ...
# 98                 Auth0           0.0        NaN       1.0  ...
# 99       Microsoft Azure           0.0        NaN       1.0  ...
# 100           Cloudflare           0.0        NaN       1.0  ...
# 101  Amazon Web Services           0.0        NaN       1.0  ...
# 102        Stripe España           0.0        NaN       1.0  ...
# 103        PayPal España           0.0        NaN       1.0  ...
# 104        Redsys España           0.0        NaN       1.0  ...
# 170                  NaN           NaN        NaN       NaN  ...
# 178                  NaN           NaN        NaN       NaN  ...
# 180                  NaN           NaN        NaN       NaN  ...
# 181                  NaN           NaN        NaN       NaN  ...
# 182                  NaN           NaN        NaN       NaN  ...
# 183                  NaN           NaN        NaN       NaN  ...
# 184                  NaN           NaN        NaN       NaN  ...
# 187                  NaN           NaN        NaN       NaN  ...
# 188                  NaN           NaN        NaN       NaN  ...
# 190                  NaN           NaN        NaN       NaN  ...
#
#                                               url_norm domain_complexity  \
# 95                         https://help.twitter.com/es          0.467092
# 96              https://www.linkedin.com/help/linkedin          0.500000
# 97   https://developer.okta.com/docs/guides/impleme...          0.430454
# 98   https://auth0.com/docs/get-started/authenticat...          0.454612
# 99               https://status.azure.com/es-es/status          0.454612
# 100                   https://www.cloudflarestatus.com          0.679179
# 101                      https://status.aws.amazon.com          0.462651
# 102             https://stripe.com/es-es/docs/payments          0.479260
# 103                   https://www.paypal.com/es/signin          0.446125
# 104                              https://www.redsys.es          0.451477
# 170              https://accounts.binance.com/es/login          0.488692
# 178                           https://web.whatsapp.com          0.500000
# 180     https://venta.renfe.com/vol/loginparticular.do          0.436826
# 181  https://www.iberia.com/es/iberiaplus/recuperar...          0.462651
# 182  https://www.iberdrola.es/wclifral/login/loginu...          0.526836
# 183                            https://login.yahoo.com          0.436826
# 184  https://www.instagram.com/accounts/password/reset          0.541505
# 187  https://www.mutua.es/acceso-area-personal/#/login          0.427394
# 188                   https://areadeclientes.mapfre.es          0.466374
# 190                         https://mibp.es/es/welcome          0.420676
#
#     host_entropy domain_whitelist_score  suspicious_path_token  token_density  \
# 95      0.166667                    0.0                    0.0            0.0
# 96      0.000000                    0.0                    0.0            0.0
# 97      0.495301                    0.0                    0.0            0.0
# 98      0.000000                    0.0                    0.0            0.0
# 99      0.239787                    0.0                    0.0            0.0
# 100     0.000000                    0.0                    0.0            0.0
# 101     0.411967                    0.0                    0.0            0.0
# 102     0.000000                    0.0                    0.0            0.0
# 103     0.000000                    0.0                    0.0            0.0
# 104     0.000000                    0.0                    0.0            0.0
# 170     0.458333                    0.0                    0.0            0.0
# 178     0.000000                    0.0                    0.0            0.0
# 180     0.241868                    0.0                    0.0            0.0
# 181     0.000000                    0.0                    0.0            0.0
# 182     0.000000                    0.0                    0.0            0.0
# 183     0.241868                    0.0                    0.0            0.0
# 184     0.000000                    0.0                    0.0            0.0
# 187     0.000000                    0.0                    0.0            0.0
# 188     0.773267                    0.0                    0.0            0.0
# 190     0.000000                    0.0                    0.0            0.0
#
#     trusted_token_context infra_risk fake_tld_in_subdomain_or_path  \
# 95                    0.0        0.0                           1.0
# 96                    0.0        0.0                           0.0
# 97                   -1.0        0.0                           0.0
# 98                   -1.0        0.0                           0.0
# 99                    0.0        0.0                           0.0
# 100                   0.0        0.0                           0.0
# 101                   0.0        0.0                           0.0
# 102                   0.0        0.0                           0.0
# 103                  -1.0        0.0                           1.0
# 104                   0.0        0.0                           0.0
# 170                  -1.0        0.0                           1.0
# 178                   0.0        0.0                           0.0
# 180                  -1.0        0.0                           0.0
# 181                   0.0        0.0                           1.0
# 182                  -1.0        0.0                           0.0
# 183                   0.0        0.0                           0.0
# 184                  -1.0        0.0                           0.0
# 187                  -1.0        0.0                           0.0
# 188                   0.0        0.0                           0.0
# 190                   0.0        0.0                           0.0
#
#     param_count_boost
# 95                0.0
# 96                0.0
# 97                0.0
# 98                0.0
# 99                0.0
# 100               0.0
# 101               0.0
# 102               0.0
# 103               0.0
# 104               0.0
# 170               0.0
# 178               0.0
# 180               0.0
# 181               0.0
# 182               0.0
# 183               0.0
# 184               0.0
# 187               0.0
# 188               0.0
# 190               0.0
#
# [20 rows x 31 columns]

# %%
# Sectorización adicional para filas con "Genérico / Otros"
# Solo modifica las filas cuyo sector actual es "Genérico / Otros"

before_generic = df[df["sector"] == "Genérico / Otros"][["url", "domain", "entidad", "matched_target", "categoria", "sector"]].head(20)
before_indices = before_generic.index

rule_counts = {
    "SaaS / Cloud / Plataformas": 0,
    "Fintech / Pagos": 0,
    "Cripto / Fintech": 0,
    "RRSS / Redes Sociales": 0,
    "Viajes / Transporte": 0,
    "Energía / Seguros": 0,
}

sector_token_map = [
    ("SaaS / Cloud / Plataformas", ["twitter", "linkedin", "okta", "auth0", "microsoft azure", "azure", "cloudflare", "aws"]),
    ("Fintech / Pagos", ["paypal", "stripe", "redsys"]),
    ("Cripto / Fintech", ["binance"]),
    ("RRSS / Redes Sociales", ["whatsapp", "instagram"]),
    ("Viajes / Transporte", ["renfe", "iberia"]),
    ("Energía / Seguros", ["iberdrola", "mutua", "mapfre"]),
]

for sector_value, tokens in sector_token_map:
    pattern = "|".join(re.escape(t) for t in tokens)
    hits = (
        df["entidad"].str.contains(pattern, case=False, na=False) |
        df["url"].str.contains(pattern, case=False, na=False) |
        df["domain"].str.contains(pattern, case=False, na=False)
    )
    mask = (df["sector"] == "Genérico / Otros") & hits
    count = int(mask.sum())
    if count:
        df.loc[mask, "sector"] = sector_value
        rule_counts[sector_value] += count

print("Filas sectorizadas por categoría (solo desde 'Genérico / Otros'):")
for categoria, cnt in rule_counts.items():
    print(f"- {categoria}: {cnt}")

after_generic = df.loc[before_indices, ["url", "domain", "entidad", "matched_target", "categoria", "sector"]]
print("\nAntes (ejemplo de 20 filas con sector Genérico / Otros):")
display(before_generic)
print("Después de aplicar las reglas adicionales:")
display(after_generic)
# Out:
# Filas sectorizadas por categoría (solo desde 'Genérico / Otros'):
# - SaaS / Cloud / Plataformas: 7
# - Fintech / Pagos: 3
# - Cripto / Fintech: 2
# - RRSS / Redes Sociales: 3
# - Viajes / Transporte: 2
# - Energía / Seguros: 3
#
# Antes (ejemplo de 20 filas con sector Genérico / Otros):
#                                                    url domain  \
# 95                         https://help.twitter.com/es    NaN
# 96              https://www.linkedin.com/help/linkedin    NaN
# 97   https://developer.okta.com/docs/guides/impleme...    NaN
# 98   https://auth0.com/docs/get-started/authenticat...    NaN
# 99               https://status.azure.com/es-es/status    NaN
# 100                  https://www.cloudflarestatus.com/    NaN
# 101                     https://status.aws.amazon.com/    NaN
# 102             https://stripe.com/es-es/docs/payments    NaN
# 103                   https://www.paypal.com/es/signin    NaN
# 104                             https://www.redsys.es/    NaN
# 170              https://accounts.binance.com/es/login    NaN
# 178                           https://web.whatsapp.com    NaN
# 180     https://venta.renfe.com/vol/loginParticular.do    NaN
# 181  https://www.iberia.com/es/iberiaplus/recuperar...    NaN
# 182  https://www.iberdrola.es/wclifral/login/loginU...    NaN
# 183                           https://login.yahoo.com/    NaN
# 184  https://www.instagram.com/accounts/password/re...    NaN
# 187  https://www.mutua.es/acceso-area-personal/#/login    NaN
# 188                   https://areadeclientes.mapfre.es    NaN
# 190                         https://mibp.es/es/welcome    NaN
#
#                  entidad  matched_target categoria            sector
# 95               Twitter             NaN       NaN  Genérico / Otros
# 96              LinkedIn             NaN       NaN  Genérico / Otros
# 97                  Okta             NaN       NaN  Genérico / Otros
# 98                 Auth0             NaN       NaN  Genérico / Otros
# 99       Microsoft Azure             NaN       NaN  Genérico / Otros
# 100           Cloudflare             NaN       NaN  Genérico / Otros
# 101  Amazon Web Services             NaN       NaN  Genérico / Otros
# 102        Stripe España             NaN       NaN  Genérico / Otros
# 103        PayPal España             NaN       NaN  Genérico / Otros
# 104        Redsys España             NaN       NaN  Genérico / Otros
# 170                  NaN         binance    cripto  Genérico / Otros
# 178                  NaN        whatsapp      rrss  Genérico / Otros
# 180                  NaN           renfe    viajes  Genérico / Otros
# 181                  NaN          iberia    viajes  Genérico / Otros
# 182                  NaN       iberdrola   energía  Genérico / Otros
# 183                  NaN           yahoo      saas  Genérico / Otros
# 184                  NaN       instagram      rrss  Genérico / Otros
# 187                  NaN  mutuamadrileña   seguros  Genérico / Otros
# 188                  NaN          mapfre   seguros  Genérico / Otros
# 190                  NaN              bp   energía  Genérico / Otros
# Después de aplicar las reglas adicionales:
#                                                    url domain  \
# 95                         https://help.twitter.com/es    NaN
# 96              https://www.linkedin.com/help/linkedin    NaN
# 97   https://developer.okta.com/docs/guides/impleme...    NaN
# 98   https://auth0.com/docs/get-started/authenticat...    NaN
# 99               https://status.azure.com/es-es/status    NaN
# 100                  https://www.cloudflarestatus.com/    NaN
# 101                     https://status.aws.amazon.com/    NaN
# 102             https://stripe.com/es-es/docs/payments    NaN
# 103                   https://www.paypal.com/es/signin    NaN
# 104                             https://www.redsys.es/    NaN
# 170              https://accounts.binance.com/es/login    NaN
# 178                           https://web.whatsapp.com    NaN
# 180     https://venta.renfe.com/vol/loginParticular.do    NaN
# 181  https://www.iberia.com/es/iberiaplus/recuperar...    NaN
# 182  https://www.iberdrola.es/wclifral/login/loginU...    NaN
# 183                           https://login.yahoo.com/    NaN
# 184  https://www.instagram.com/accounts/password/re...    NaN
# 187  https://www.mutua.es/acceso-area-personal/#/login    NaN
# 188                   https://areadeclientes.mapfre.es    NaN
# 190                         https://mibp.es/es/welcome    NaN
#
#                  entidad  matched_target categoria                      sector
# 95               Twitter             NaN       NaN  SaaS / Cloud / Plataformas
# 96              LinkedIn             NaN       NaN  SaaS / Cloud / Plataformas
# 97                  Okta             NaN       NaN  SaaS / Cloud / Plataformas
# 98                 Auth0             NaN       NaN  SaaS / Cloud / Plataformas
# 99       Microsoft Azure             NaN       NaN  SaaS / Cloud / Plataformas
# 100           Cloudflare             NaN       NaN  SaaS / Cloud / Plataformas
# 101  Amazon Web Services             NaN       NaN  SaaS / Cloud / Plataformas
# 102        Stripe España             NaN       NaN             Fintech / Pagos
# 103        PayPal España             NaN       NaN             Fintech / Pagos
# 104        Redsys España             NaN       NaN             Fintech / Pagos
# 170                  NaN         binance    cripto            Cripto / Fintech
# 178                  NaN        whatsapp      rrss       RRSS / Redes Sociales
# 180                  NaN           renfe    viajes         Viajes / Transporte
# 181                  NaN          iberia    viajes         Viajes / Transporte
# 182                  NaN       iberdrola   energía           Energía / Seguros
# 183                  NaN           yahoo      saas            Genérico / Otros
# 184                  NaN       instagram      rrss       RRSS / Redes Sociales
# 187                  NaN  mutuamadrileña   seguros           Energía / Seguros
# 188                  NaN          mapfre   seguros           Energía / Seguros
# 190                  NaN              bp   energía            Genérico / Otros

# %%
# Sectorización final usando únicamente la columna `entidad` sobre Genérico / Otros
# Reglas: solo filas con sector == "Genérico / Otros" y sin sobrescribir sectores válidos

entidad_normalizada = (
    df["entidad"]
    .astype(str)
    .str.lower()
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

entidad_sector_map = {
    # SaaS / Cloud / Plataformas
    "twitter": "SaaS / Cloud / Plataformas",
    "linkedin": "SaaS / Cloud / Plataformas",
    "okta": "SaaS / Cloud / Plataformas",
    "auth0": "SaaS / Cloud / Plataformas",
    "microsoft azure": "SaaS / Cloud / Plataformas",
    "cloudflare": "SaaS / Cloud / Plataformas",
    "amazon web services": "SaaS / Cloud / Plataformas",
    # Fintech / Pagos
    "stripe españa": "Fintech / Pagos",
    "paypal españa": "Fintech / Pagos",
    "redsys españa": "Fintech / Pagos",
}

proposed_sector = entidad_normalizada.map(entidad_sector_map)
mask_generic = df["sector"] == "Genérico / Otros"
mask_assign = mask_generic & proposed_sector.notna()

# Asignar sectores solo a las filas Genérico / Otros con entidad mapeada
if mask_assign.any():
    df.loc[mask_assign, "sector"] = proposed_sector[mask_assign]

# Contadores por categoría asignada en esta pasada
counts_assigned = proposed_sector[mask_assign].value_counts().to_dict()
print("Filas sectorizadas por categoría (solo desde 'Genérico / Otros' usando entidad):")
for categoria in [
    "SaaS / Cloud / Plataformas",
    "Fintech / Pagos",
]:
    print(f"- {categoria}: {counts_assigned.get(categoria, 0)}")

# df_gen actualizado tras la asignación
df_gen = df[df["sector"] == "Genérico / Otros"].copy()
print(f"\nFilas restantes en df_gen (Genérico / Otros): {len(df_gen)}")
display(df_gen.head(20))
# Out:
# Filas sectorizadas por categoría (solo desde 'Genérico / Otros' usando entidad):
# - SaaS / Cloud / Plataformas: 0
# - Fintech / Pagos: 0
#
# Filas restantes en df_gen (Genérico / Otros): 66
#     campaign categoria  confianza  confidence dataset_split  \
# 183      NaN      saas        NaN         NaN           NaN
# 190      NaN   energía        NaN         NaN           NaN
# 191      NaN    gaming        NaN         NaN           NaN
# 194      NaN      saas        NaN         NaN           NaN
# 203      NaN      saas        NaN         NaN           NaN
# 204      NaN    cripto        NaN         NaN           NaN
# 209      NaN    cripto        NaN         NaN           NaN
# 212      NaN    gaming        NaN         NaN           NaN
# 213      NaN      saas        NaN         NaN           NaN
# 214      NaN    gaming        NaN         NaN           NaN
# 215      NaN      saas        NaN         NaN           NaN
# 218      NaN      saas        NaN         NaN           NaN
# 219      NaN      saas        NaN         NaN           NaN
# 222      NaN    cripto        NaN         NaN           NaN
# 236      NaN      saas        NaN         NaN           NaN
# 241      NaN      saas        NaN         NaN           NaN
# 247      NaN       NaN       90.0         NaN     train_val
# 251      NaN       NaN       90.0         NaN     train_val
# 252      NaN       NaN       90.0         NaN     train_val
# 253      NaN       NaN       90.0         NaN     train_val
#
#                                                 domain   entidad  \
# 183                                                NaN       NaN
# 190                                                NaN       NaN
# 191                                                NaN       NaN
# 194                                                NaN       NaN
# 203                                                NaN       NaN
# 204                                                NaN       NaN
# 209                                                NaN       NaN
# 212                                                NaN       NaN
# 213                                                NaN       NaN
# 214                                                NaN       NaN
# 215                                                NaN       NaN
# 218                                                NaN       NaN
# 219                                                NaN       NaN
# 222                                                NaN       NaN
# 236                                                NaN       NaN
# 241                                                NaN       NaN
# 247  webseguridadcuenta-9e626b.ingress-bonde.easywp...  Generico
# 251        suponsoro22-ba9799.ingress-daribow.ewp.live  Generico
# 252         suponsoo22-ba6aa2.ingress-florina.ewp.live  Generico
# 253          supoertas22-bb468f.ingress-bonde.ewp.live  Generico
#
#      free_hosting  inclusion  is_https  ...  \
# 183           NaN        NaN       NaN  ...
# 190           NaN        NaN       NaN  ...
# 191           NaN        NaN       NaN  ...
# 194           NaN        NaN       NaN  ...
# 203           NaN        NaN       NaN  ...
# 204           NaN        NaN       NaN  ...
# 209           NaN        NaN       NaN  ...
# 212           NaN        NaN       NaN  ...
# 213           NaN        NaN       NaN  ...
# 214           NaN        NaN       NaN  ...
# 215           NaN        NaN       NaN  ...
# 218           NaN        NaN       NaN  ...
# 219           NaN        NaN       NaN  ...
# 222           NaN        NaN       NaN  ...
# 236           NaN        NaN       NaN  ...
# 241           NaN        NaN       NaN  ...
# 247           NaN        1.0       NaN  ...
# 251           NaN        1.0       NaN  ...
# 252           NaN        1.0       NaN  ...
# 253           NaN        1.0       NaN  ...
#
#                                               url_norm domain_complexity  \
# 183                            https://login.yahoo.com          0.436826
# 190                         https://mibp.es/es/welcome          0.420676
# 191                               https://www.habbo.es          0.427394
# 194                             https://wetransfer.com          0.554320
# 203                https://www.dropbox.com/es_es/login          0.488692
# 204                     https://www.coinbase.com/es-es          0.529964
# 209                    https://help.coinbase.com/es-es          0.529964
# 212                    https://www.roblox.com/es/login          0.462651
# 213                            https://zoom.us/es/join          0.403717
# 214  https://www.roblox.com/es/upgrades/robux?ctx=n...          0.462651
# 215  https://accounts.google.com/servicelogin?servi...          0.446125
# 218  https://www.ionos.es/ayuda/sitios-web-tiendas/...          0.427394
# 219  https://www.ionos.es/ayuda/mi-cuenta/gestionar...          0.427394
# 222                              https://bit2me.com/es          0.479260
# 236  https://www.microsoft.com/es-es/microsoft-365/...          0.541505
# 241  https://www.ionos.es/ayuda/mi-cuenta/factura-1...          0.427394
# 247  http://webseguridadcuenta-9e626b.ingress-bonde...          0.479260
# 251  https://suponsoro22-ba9799.ingress-daribow.ewp...          0.508495
# 252  https://suponsoo22-ba6aa2.ingress-florina.ewp....          0.508495
# 253  https://supoertas22-bb468f.ingress-bonde.ewp.l...          0.508495
#
#     host_entropy domain_whitelist_score  suspicious_path_token  token_density  \
# 183     0.241868                    0.0                    0.0       0.000000
# 190     0.000000                    0.0                    0.0       0.000000
# 191     0.000000                    0.0                    0.0       0.000000
# 194     0.000000                    0.0                    0.0       0.000000
# 203     0.000000                    0.0                    0.0       0.000000
# 204     0.000000                    0.0                    0.0       0.000000
# 209     0.166667                    0.0                    0.0       0.000000
# 212     0.000000                    0.0                    0.0       0.000000
# 213     0.000000                    0.0                    0.0       0.000000
# 214     0.000000                    0.0                    0.0       0.000000
# 215     0.458333                    0.0                    0.0       0.000000
# 218     0.000000                    0.0                    1.0       0.090909
# 219     0.000000                    0.0                    0.0       0.000000
# 222     0.000000                    0.0                    0.0       0.000000
# 236     0.000000                    0.0                    0.0       0.000000
# 241     0.000000                    0.0                    0.0       0.000000
# 247     0.992710                    0.0                    1.0       0.107143
# 251     0.976934                    0.0                    0.0       0.000000
# 252     0.941330                    0.0                    0.0       0.000000
# 253     1.000000                    0.0                    0.0       0.000000
#
#     trusted_token_context infra_risk fake_tld_in_subdomain_or_path  \
# 183                   0.0        0.0                           0.0
# 190                   0.0        0.0                           0.0
# 191                   0.0        0.0                           0.0
# 194                   0.0        0.0                           0.0
# 203                  -1.0        0.0                           0.0
# 204                   0.0        0.0                           1.0
# 209                   0.0        0.0                           1.0
# 212                  -1.0        0.0                           1.0
# 213                   0.0        0.0                           1.0
# 214                   0.0        0.0                           1.0
# 215                  -1.0        0.0                           0.0
# 218                   0.0        0.0                           0.0
# 219                  -1.0        0.0                           0.0
# 222                   0.0        0.0                           1.0
# 236                   0.0        0.0                           0.0
# 241                  -1.0        0.0                           0.0
# 247                  -1.0        0.3                           0.0
# 251                  -1.0        3.0                           1.0
# 252                  -1.0        3.0                           1.0
# 253                  -1.0        3.0                           1.0
#
#     param_count_boost
# 183          0.000000
# 190          0.000000
# 191          0.000000
# 194          0.000000
# 203          0.000000
# 204          0.000000
# 209          0.000000
# 212          0.000000
# 213          0.000000
# 214          0.500000
# 215          0.500000
# 218          0.000000
# 219          0.000000
# 222          0.000000
# 236          0.000000
# 241          0.000000
# 247          0.666667
# 251          0.000000
# 252          0.000000
# 253          0.500000
#
# [20 rows x 31 columns]

# %%
# Sectorización adicional solo usando `entidad` normalizada para filas Genérico / Otros

# 1. Columna temporal normalizada
df["entidad_norm"] = df["entidad"].astype(str).str.lower().str.strip().fillna("")

# 2. Reglas sobre entidad_norm
entidad_sector_map_norm = {
    # SaaS / Cloud / Plataformas
    "twitter": "SaaS / Cloud / Plataformas",
    "linkedin": "SaaS / Cloud / Plataformas",
    "okta": "SaaS / Cloud / Plataformas",
    "auth0": "SaaS / Cloud / Plataformas",
    "microsoft azure": "SaaS / Cloud / Plataformas",
    "cloudflare": "SaaS / Cloud / Plataformas",
    "amazon web services": "SaaS / Cloud / Plataformas",
    # Fintech / Pagos
    "stripe españa": "Fintech / Pagos",
    "paypal españa": "Fintech / Pagos",
    "redsys españa": "Fintech / Pagos",
}

proposed_sector_norm = df["entidad_norm"].map(entidad_sector_map_norm)
mask_generic = df["sector"] == "Genérico / Otros"
mask_assign = mask_generic & proposed_sector_norm.notna()

# 3-4. Asignar solo donde sigue siendo Genérico / Otros y hay match en entidad_norm
if mask_assign.any():
    df.loc[mask_assign, "sector"] = proposed_sector_norm[mask_assign]

# 5. Contadores por categoría
counts_assigned_norm = proposed_sector_norm[mask_assign].value_counts().to_dict()
print("Filas sectorizadas por categoría (usando entidad_norm desde 'Genérico / Otros'):")
for categoria in [
    "SaaS / Cloud / Plataformas",
    "Fintech / Pagos",
]:
    print(f"- {categoria}: {counts_assigned_norm.get(categoria, 0)}")

# 6. Count final de Genérico / Otros
remaining_generic = int((df["sector"] == "Genérico / Otros").sum())
print(f"\nFilas restantes en 'Genérico / Otros': {remaining_generic}")

# Limpiar columna temporal
df.drop(columns=["entidad_norm"], inplace=True)

# Mostrar ejemplo de 20 filas restantes en Genérico / Otros
if remaining_generic:
    display(df[df["sector"] == "Genérico / Otros"].head(20))
# Out:
# Filas sectorizadas por categoría (usando entidad_norm desde 'Genérico / Otros'):
# - SaaS / Cloud / Plataformas: 0
# - Fintech / Pagos: 0
#
# Filas restantes en 'Genérico / Otros': 66
#     campaign categoria  confianza  confidence dataset_split  \
# 183      NaN      saas        NaN         NaN           NaN
# 190      NaN   energía        NaN         NaN           NaN
# 191      NaN    gaming        NaN         NaN           NaN
# 194      NaN      saas        NaN         NaN           NaN
# 203      NaN      saas        NaN         NaN           NaN
# 204      NaN    cripto        NaN         NaN           NaN
# 209      NaN    cripto        NaN         NaN           NaN
# 212      NaN    gaming        NaN         NaN           NaN
# 213      NaN      saas        NaN         NaN           NaN
# 214      NaN    gaming        NaN         NaN           NaN
# 215      NaN      saas        NaN         NaN           NaN
# 218      NaN      saas        NaN         NaN           NaN
# 219      NaN      saas        NaN         NaN           NaN
# 222      NaN    cripto        NaN         NaN           NaN
# 236      NaN      saas        NaN         NaN           NaN
# 241      NaN      saas        NaN         NaN           NaN
# 247      NaN       NaN       90.0         NaN     train_val
# 251      NaN       NaN       90.0         NaN     train_val
# 252      NaN       NaN       90.0         NaN     train_val
# 253      NaN       NaN       90.0         NaN     train_val
#
#                                                 domain   entidad  \
# 183                                                NaN       NaN
# 190                                                NaN       NaN
# 191                                                NaN       NaN
# 194                                                NaN       NaN
# 203                                                NaN       NaN
# 204                                                NaN       NaN
# 209                                                NaN       NaN
# 212                                                NaN       NaN
# 213                                                NaN       NaN
# 214                                                NaN       NaN
# 215                                                NaN       NaN
# 218                                                NaN       NaN
# 219                                                NaN       NaN
# 222                                                NaN       NaN
# 236                                                NaN       NaN
# 241                                                NaN       NaN
# 247  webseguridadcuenta-9e626b.ingress-bonde.easywp...  Generico
# 251        suponsoro22-ba9799.ingress-daribow.ewp.live  Generico
# 252         suponsoo22-ba6aa2.ingress-florina.ewp.live  Generico
# 253          supoertas22-bb468f.ingress-bonde.ewp.live  Generico
#
#      free_hosting  inclusion  is_https  ...  \
# 183           NaN        NaN       NaN  ...
# 190           NaN        NaN       NaN  ...
# 191           NaN        NaN       NaN  ...
# 194           NaN        NaN       NaN  ...
# 203           NaN        NaN       NaN  ...
# 204           NaN        NaN       NaN  ...
# 209           NaN        NaN       NaN  ...
# 212           NaN        NaN       NaN  ...
# 213           NaN        NaN       NaN  ...
# 214           NaN        NaN       NaN  ...
# 215           NaN        NaN       NaN  ...
# 218           NaN        NaN       NaN  ...
# 219           NaN        NaN       NaN  ...
# 222           NaN        NaN       NaN  ...
# 236           NaN        NaN       NaN  ...
# 241           NaN        NaN       NaN  ...
# 247           NaN        1.0       NaN  ...
# 251           NaN        1.0       NaN  ...
# 252           NaN        1.0       NaN  ...
# 253           NaN        1.0       NaN  ...
#
#                                               url_norm domain_complexity  \
# 183                            https://login.yahoo.com          0.436826
# 190                         https://mibp.es/es/welcome          0.420676
# 191                               https://www.habbo.es          0.427394
# 194                             https://wetransfer.com          0.554320
# 203                https://www.dropbox.com/es_es/login          0.488692
# 204                     https://www.coinbase.com/es-es          0.529964
# 209                    https://help.coinbase.com/es-es          0.529964
# 212                    https://www.roblox.com/es/login          0.462651
# 213                            https://zoom.us/es/join          0.403717
# 214  https://www.roblox.com/es/upgrades/robux?ctx=n...          0.462651
# 215  https://accounts.google.com/servicelogin?servi...          0.446125
# 218  https://www.ionos.es/ayuda/sitios-web-tiendas/...          0.427394
# 219  https://www.ionos.es/ayuda/mi-cuenta/gestionar...          0.427394
# 222                              https://bit2me.com/es          0.479260
# 236  https://www.microsoft.com/es-es/microsoft-365/...          0.541505
# 241  https://www.ionos.es/ayuda/mi-cuenta/factura-1...          0.427394
# 247  http://webseguridadcuenta-9e626b.ingress-bonde...          0.479260
# 251  https://suponsoro22-ba9799.ingress-daribow.ewp...          0.508495
# 252  https://suponsoo22-ba6aa2.ingress-florina.ewp....          0.508495
# 253  https://supoertas22-bb468f.ingress-bonde.ewp.l...          0.508495
#
#     host_entropy domain_whitelist_score  suspicious_path_token  token_density  \
# 183     0.241868                    0.0                    0.0       0.000000
# 190     0.000000                    0.0                    0.0       0.000000
# 191     0.000000                    0.0                    0.0       0.000000
# 194     0.000000                    0.0                    0.0       0.000000
# 203     0.000000                    0.0                    0.0       0.000000
# 204     0.000000                    0.0                    0.0       0.000000
# 209     0.166667                    0.0                    0.0       0.000000
# 212     0.000000                    0.0                    0.0       0.000000
# 213     0.000000                    0.0                    0.0       0.000000
# 214     0.000000                    0.0                    0.0       0.000000
# 215     0.458333                    0.0                    0.0       0.000000
# 218     0.000000                    0.0                    1.0       0.090909
# 219     0.000000                    0.0                    0.0       0.000000
# 222     0.000000                    0.0                    0.0       0.000000
# 236     0.000000                    0.0                    0.0       0.000000
# 241     0.000000                    0.0                    0.0       0.000000
# 247     0.992710                    0.0                    1.0       0.107143
# 251     0.976934                    0.0                    0.0       0.000000
# 252     0.941330                    0.0                    0.0       0.000000
# 253     1.000000                    0.0                    0.0       0.000000
#
#     trusted_token_context infra_risk fake_tld_in_subdomain_or_path  \
# 183                   0.0        0.0                           0.0
# 190                   0.0        0.0                           0.0
# 191                   0.0        0.0                           0.0
# 194                   0.0        0.0                           0.0
# 203                  -1.0        0.0                           0.0
# 204                   0.0        0.0                           1.0
# 209                   0.0        0.0                           1.0
# 212                  -1.0        0.0                           1.0
# 213                   0.0        0.0                           1.0
# 214                   0.0        0.0                           1.0
# 215                  -1.0        0.0                           0.0
# 218                   0.0        0.0                           0.0
# 219                  -1.0        0.0                           0.0
# 222                   0.0        0.0                           1.0
# 236                   0.0        0.0                           0.0
# 241                  -1.0        0.0                           0.0
# 247                  -1.0        0.3                           0.0
# 251                  -1.0        3.0                           1.0
# 252                  -1.0        3.0                           1.0
# 253                  -1.0        3.0                           1.0
#
#     param_count_boost
# 183          0.000000
# 190          0.000000
# 191          0.000000
# 194          0.000000
# 203          0.000000
# 204          0.000000
# 209          0.000000
# 212          0.000000
# 213          0.000000
# 214          0.500000
# 215          0.500000
# 218          0.000000
# 219          0.000000
# 222          0.000000
# 236          0.000000
# 241          0.000000
# 247          0.666667
# 251          0.000000
# 252          0.000000
# 253          0.500000
#
# [20 rows x 31 columns]

# %%
# Sectorización usando `categoria` como regla principal sobre filas Genérico / Otros

categoria_norm = df["categoria"].astype(str).str.lower().str.strip()

categoria_sector_map = {
    "saas": "SaaS / Cloud / Plataformas",
    "viajes": "Viajes / Transporte",
    "energía": "Energía / Seguros",
    "energia": "Energía / Seguros",
    "seguros": "Energía / Seguros",
    "cripto": "Cripto / Fintech",
    "rrss": "RRSS / Redes Sociales",
    "gaming": "Gaming",
    "e-commerce": "Retail / e-commerce / Streaming",
    "streaming": "Retail / e-commerce / Streaming",
}

proposed_sector_cat = categoria_norm.map(categoria_sector_map)
mask_generic = df["sector"] == "Genérico / Otros"
mask_assign = mask_generic & proposed_sector_cat.notna()

if mask_assign.any():
    df.loc[mask_assign, "sector"] = proposed_sector_cat[mask_assign]

counts_assigned_cat = proposed_sector_cat[mask_assign].value_counts().to_dict()
print("Filas sectorizadas por categoría (usando categoria_norm desde 'Genérico / Otros'):")
for categoria in [
    "SaaS / Cloud / Plataformas",
    "Viajes / Transporte",
    "Energía / Seguros",
    "Cripto / Fintech",
    "RRSS / Redes Sociales",
    "Gaming",
    "Retail / e-commerce / Streaming",
]:
    print(f"- {categoria}: {counts_assigned_cat.get(categoria, 0)}")

remaining_generic = int((df["sector"] == "Genérico / Otros").sum())
print(f"\nFilas restantes en 'Genérico / Otros': {remaining_generic}")
if remaining_generic:
    display(df[df["sector"] == "Genérico / Otros"].head(20))
# Out:
# Filas sectorizadas por categoría (usando categoria_norm desde 'Genérico / Otros'):
# - SaaS / Cloud / Plataformas: 17
# - Viajes / Transporte: 0
# - Energía / Seguros: 2
# - Cripto / Fintech: 5
# - RRSS / Redes Sociales: 0
# - Gaming: 6
# - Retail / e-commerce / Streaming: 0
#
# Filas restantes en 'Genérico / Otros': 36
#                                               campaign categoria  confianza  \
# 247                                                NaN       NaN       90.0
# 251                                                NaN       NaN       90.0
# 252                                                NaN       NaN       90.0
# 253                                                NaN       NaN       90.0
# 254                                                NaN       NaN       90.0
# 261                                                NaN       NaN       90.0
# 262                                                NaN       NaN       90.0
# 268                                                NaN       NaN       90.0
# 305                                                NaN       NaN       90.0
# 338                                                NaN       NaN       90.0
# 343                                                NaN       NaN       90.0
# 344                                                NaN       NaN       90.0
# 345                                                NaN       NaN       90.0
# 361                                                NaN       NaN       90.0
# 362                                                NaN       NaN       90.0
# 363                                                NaN       NaN       90.0
# 364                                                NaN       NaN       90.0
# 365                                                NaN       NaN       90.0
# 368                          weebly.com/recibo-de-pago  genérico        NaN
# 372  sites.google.com/view/habilitaciondeacceso/pág...  genérico        NaN
#
#      confidence dataset_split  \
# 247         NaN     train_val
# 251         NaN     train_val
# 252         NaN     train_val
# 253         NaN     train_val
# 254         NaN     train_val
# 261         NaN     train_val
# 262         NaN     train_val
# 268         NaN     train_val
# 305         NaN     train_val
# 338         NaN     train_val
# 343         NaN     train_val
# 344         NaN     train_val
# 345         NaN     train_val
# 361         NaN     train_val
# 362         NaN     train_val
# 363         NaN     train_val
# 364         NaN     train_val
# 365         NaN     train_val
# 368         NaN           NaN
# 372         NaN           NaN
#
#                                                 domain   entidad  \
# 247  webseguridadcuenta-9e626b.ingress-bonde.easywp...  Generico
# 251        suponsoro22-ba9799.ingress-daribow.ewp.live  Generico
# 252         suponsoo22-ba6aa2.ingress-florina.ewp.live  Generico
# 253          supoertas22-bb468f.ingress-bonde.ewp.live  Generico
# 254          supanort22-baa4c7.ingress-erytho.ewp.live  Generico
# 261  particulares-es-b965d0.ingress-comporellon.ewp...  Generico
# 262  particulares-es-1-bd5e31.ingress-daribow.ewp.live  Generico
# 268  informacion-cliente-spainespain34122306.codean...  Generico
# 305  cuentainformacion-b8eb22.ingress-comporellon.e...  Generico
# 338  confirmacion-cuenta-1-9cd542.ingress-comporell...  Generico
# 343             bixtnet-c439fe.ingress-erytho.ewp.live  Generico
# 344                      appvirtual.cloudbanshag.cloud  Generico
# 345              acceso-ba004e.ingress-baronn.ewp.live  Generico
# 361                 2333-b5e370.ingress-earth.ewp.live  Generico
# 362  mi-cuenta-informacion-b58175.ingress-baronn.ew...  Generico
# 363    clientes-servicio-b9f795.ingress-earth.ewp.live  Generico
# 364                  alertanotificacionesdinamicos.com  Generico
# 365  servicioelportal-particulare-bc8925.ingress-da...  Generico
# 368                                                NaN       NaN
# 372                                                NaN       NaN
#
#      free_hosting  inclusion  is_https  ...  \
# 247           NaN        1.0       NaN  ...
# 251           NaN        1.0       NaN  ...
# 252           NaN        1.0       NaN  ...
# 253           NaN        1.0       NaN  ...
# 254           NaN        1.0       NaN  ...
# 261           NaN        1.0       NaN  ...
# 262           NaN        1.0       NaN  ...
# 268           NaN        1.0       NaN  ...
# 305           NaN        1.0       NaN  ...
# 338           NaN        1.0       NaN  ...
# 343           NaN        1.0       NaN  ...
# 344           NaN        1.0       NaN  ...
# 345           NaN        1.0       NaN  ...
# 361           NaN        1.0       NaN  ...
# 362           NaN        1.0       NaN  ...
# 363           NaN        1.0       NaN  ...
# 364           NaN        1.0       NaN  ...
# 365           NaN        1.0       NaN  ...
# 368           NaN        NaN       NaN  ...
# 372           NaN        NaN       NaN  ...
#
#                                               url_norm domain_complexity  \
# 247  http://webseguridadcuenta-9e626b.ingress-bonde...          0.479260
# 251  https://suponsoro22-ba9799.ingress-daribow.ewp...          0.508495
# 252  https://suponsoo22-ba6aa2.ingress-florina.ewp....          0.508495
# 253  https://supoertas22-bb468f.ingress-bonde.ewp.l...          0.508495
# 254  https://supanort22-baa4c7.ingress-erytho.ewp.l...          0.508495
# 261  https://particulares-es-b965d0.ingress-compore...          0.508495
# 262  https://particulares-es-1-bd5e31.ingress-darib...          0.508495
# 268  https://informacion-cliente-spainespain3412230...          0.554320
# 305  https://cuentainformacion-b8eb22.ingress-compo...          0.508495
# 338  https://confirmacion-cuenta-1-9cd542.ingress-c...          0.479260
# 343  https://bixtnet-c439fe.ingress-erytho.ewp.live...          0.508495
# 344  https://appvirtual.cloudbanshag.cloud/verifica...          0.652622
# 345  https://acceso-ba004e.ingress-baronn.ewp.live/...          0.508495
# 361  https://2333-b5e370.ingress-earth.ewp.live/acc...          0.508495
# 362  https://mi-cuenta-informacion-b58175.ingress-b...          0.508495
# 363  https://clientes-servicio-b9f795.ingress-earth...          0.508495
# 364  http://alertanotificacionesdinamicos.com/verif...          0.688518
# 365  https://servicioelportal-particulare-bc8925.in...          0.508495
# 368                  https://recibo-de-pago.weebly.com          0.462651
# 372  https://sites.google.com/view/habilitaciondeac...          0.446125
#
#     host_entropy domain_whitelist_score  suspicious_path_token  token_density  \
# 247     0.992710                    0.0                    1.0       0.107143
# 251     0.976934                    0.0                    0.0       0.000000
# 252     0.941330                    0.0                    0.0       0.000000
# 253     1.000000                    0.0                    0.0       0.000000
# 254     1.000000                    0.0                    0.0       0.000000
# 261     1.000000                    0.0                    0.0       0.000000
# 262     1.000000                    0.0                    0.0       0.000000
# 268     1.000000                    0.0                    0.0       0.000000
# 305     1.000000                    0.0                    0.0       0.000000
# 338     1.000000                    0.0                    0.0       0.000000
# 343     0.998670                    0.0                    0.0       0.000000
# 344     0.608735                    0.0                    1.0       0.691358
# 345     0.901504                    0.0                    0.0       0.000000
# 361     0.950877                    0.0                    0.0       0.000000
# 362     1.000000                    0.0                    0.0       0.000000
# 363     0.997502                    0.0                    0.0       0.000000
# 364     0.000000                    0.0                    0.0       0.194444
# 365     1.000000                    0.0                    0.0       0.000000
# 368     0.844696                    0.0                    0.0       0.000000
# 372     0.200201                    0.0                    0.0       0.000000
#
#     trusted_token_context infra_risk fake_tld_in_subdomain_or_path  \
# 247                  -1.0        0.3                           0.0
# 251                  -1.0        3.0                           1.0
# 252                  -1.0        3.0                           1.0
# 253                  -1.0        3.0                           1.0
# 254                  -1.0        3.0                           1.0
# 261                  -1.0        3.0                           1.0
# 262                  -1.0        3.0                           1.0
# 268                   0.0        0.0                           0.0
# 305                  -1.0        3.0                           0.0
# 338                  -1.0        0.0                           1.0
# 343                   0.0        3.0                           0.0
# 344                   0.0        0.0                           0.0
# 345                  -1.0        3.0                           0.0
# 361                  -1.0        3.0                           1.0
# 362                  -1.0        3.0                           1.0
# 363                  -1.0        3.0                           0.0
# 364                   0.0        0.3                           0.0
# 365                  -1.0        3.0                           1.0
# 368                   0.0        1.0                           0.0
# 372                  -1.0        0.0                           0.0
#
#     param_count_boost
# 247          0.666667
# 251          0.000000
# 252          0.000000
# 253          0.500000
# 254          0.000000
# 261          0.000000
# 262          0.500000
# 268          0.000000
# 305          0.000000
# 338          0.000000
# 343          0.000000
# 344          0.000000
# 345          0.000000
# 361          0.500000
# 362          0.000000
# 363          0.000000
# 364          0.000000
# 365          0.000000
# 368          0.000000
# 372          0.000000
#
# [20 rows x 31 columns]

# %%
# Marcar URLs de dominios acortadores como excluidas
import numpy as np

acortadores = {
    "bit.ly",
    "tinyurl.com",
    "t.co",
    "is.gd",
    "qrco.de",
    "cutt.ly",
    "rebrand.ly",
    "goo.gl",
    "shorturl.at",
}

mask_acortador = df["domain"].astype(str).str.lower().str.strip().isin(acortadores)
num_excluidas = int(mask_acortador.sum())

if num_excluidas:
    # exclude_flag = 1
    df.loc[mask_acortador, "exclude_flag"] = 1
    # exclude_reason += "acortador"
    existing_reason = df.loc[mask_acortador, "exclude_reason"].fillna("").astype(str).str.strip()
    df.loc[mask_acortador, "exclude_reason"] = np.where(
        existing_reason == "", "acortador", existing_reason + " | acortador"
    )

print(f"Filas marcadas como excluidas por acortador: {num_excluidas}")
# Out:
# Filas marcadas como excluidas por acortador: 0

# %%
# Recalcular columna `domain` usando tldextract sobre `url_norm`
import tldextract

def extract_domain(url):
    try:
        if pd.isna(url):
            return ""
        ext = tldextract.extract(str(url))
        return ext.registered_domain or ""
    except Exception:
        return ""

# Recalcular dominio ignorando el valor previo
df["domain"] = df["url_norm"].apply(extract_domain)

# Contar dominios vacíos
domain_empty_count = int((df["domain"] == "").sum())
print(f"Filas con domain vacío tras recalcular: {domain_empty_count}")

# Mostrar los 20 primeros dominios recalculados
display(df["domain"].head(20))

# %%
# Marcar como excluidas las URLs cuyo dominio es un acortador (lista ampliada)
import numpy as np

acortadores_ext = {
    "bit.ly", "tinyurl.com", "t.co", "is.gd", "qrco.de", "cutt.ly",
    "rebrand.ly", "shorturl.at", "shrtco.de", "rb.gy", "v.gd", "s.id", "goo.gl",
}

mask_acortador_ext = df["domain"].astype(str).str.lower().str.strip().isin(acortadores_ext)
num_excluidas_ext = int(mask_acortador_ext.sum())

if num_excluidas_ext:
    df.loc[mask_acortador_ext, "exclude_flag"] = 1
    existing_reason = df.loc[mask_acortador_ext, "exclude_reason"].fillna("").astype(str).str.strip()
    df.loc[mask_acortador_ext, "exclude_reason"] = np.where(
        existing_reason == "", "acortador", existing_reason + ";acortador"
    )

print(f"Filas marcadas como excluidas por acortador (lista ampliada): {num_excluidas_ext}")
# Out:
# Filas marcadas como excluidas por acortador (lista ampliada): 1

# %%
# Asegurar columnas exclude_flag y exclude_reason, y re-ejecutar exclusión por acortadores
import numpy as np

if "exclude_flag" not in df.columns:
    df["exclude_flag"] = 0
if "exclude_reason" not in df.columns:
    df["exclude_reason"] = ""

acortadores_ext = {
    "bit.ly", "tinyurl.com", "t.co", "is.gd", "qrco.de", "cutt.ly",
    "rebrand.ly", "shorturl.at", "shrtco.de", "rb.gy", "v.gd", "s.id", "goo.gl",
}

mask_acortador_ext = df["domain"].astype(str).str.lower().str.strip().isin(acortadores_ext)
num_excluidas_ext = int(mask_acortador_ext.sum())

if num_excluidas_ext:
    df.loc[mask_acortador_ext, "exclude_flag"] = 1
    existing_reason = df.loc[mask_acortador_ext, "exclude_reason"].fillna("").astype(str).str.strip()
    df.loc[mask_acortador_ext, "exclude_reason"] = np.where(
        existing_reason == "", "acortador", existing_reason + ";acortador"
    )

print(f"Filas marcadas como excluidas por acortador (lista ampliada): {num_excluidas_ext}")
# Out:
# Filas marcadas como excluidas por acortador (lista ampliada): 1

# %%
# Recalcular columna `domain` usando tldextract sobre `url_norm` (al final)
import tldextract

def extract_domain(url):
    try:
        if pd.isna(url):
            return ""
        ext = tldextract.extract(str(url))
        return ext.registered_domain or ""
    except Exception:
        return ""

# Recalcular dominio ignorando el valor previo
df["domain"] = df["url_norm"].apply(extract_domain)

# Contar dominios vacíos
domain_empty_count = int((df["domain"] == "").sum())
print(f"Filas con domain vacío tras recalcular: {domain_empty_count}")

# Mostrar los 20 primeros dominios recalculados
display(df["domain"].head(20))

# %%
# Sectorizar filas que quedaron como "Genérico / Otros" usando entidad o tokens en URL/domain
before_gen = df[df["sector"] == "Genérico / Otros"][
    ["url", "domain", "entidad", "categoria", "sector"]
].head(20)
before_indices = before_gen.index

# Reglas de tokens por sector, priorizadas en este orden
sector_token_rules = [
    ("SaaS / Cloud / Plataformas", ["twitter", "linkedin", "okta", "auth0", "azure", "microsoft azure", "cloudflare", "aws"]),
    ("Fintech / Pagos", ["paypal", "stripe", "redsys"]),
    ("Cripto / Fintech", ["binance"]),
    ("RRSS / Redes Sociales", ["whatsapp", "instagram"]),
    ("Viajes / Transporte", ["renfe", "iberia"]),
    ("Energía / Seguros", ["iberdrola", "mutua", "mapfre"]),
]

filled_counts = {label: 0 for label, _ in sector_token_rules}

# Solo modificamos filas que sigan en "Genérico / Otros"
gen_mask = df["sector"] == "Genérico / Otros"

for sector_label, tokens in sector_token_rules:
    token_pattern = "|".join(re.escape(t) for t in tokens)
    matches = (
        df["entidad"].str.contains(token_pattern, case=False, na=False)
        | df["url"].str.contains(token_pattern, case=False, na=False)
        | df["domain"].str.contains(token_pattern, case=False, na=False)
    )
    apply_mask = gen_mask & matches
    count = int(apply_mask.sum())
    if count:
        df.loc[apply_mask, "sector"] = sector_label
        filled_counts[sector_label] += count
        # Actualizamos máscara para no sobrescribir en iteraciones siguientes
        gen_mask = df["sector"] == "Genérico / Otros"

print("Filas sectorizadas por categoría adicional:")
for label, count in filled_counts.items():
    print(f"- {label}: {count}")

# df_gen actualizado tras la sectorización adicional
df_gen = df[df["sector"] == "Genérico / Otros"].copy()
print(f"\nFilas restantes en df_gen (Genérico / Otros): {len(df_gen)}")

after_gen = df.loc[before_indices, ["url", "domain", "entidad", "categoria", "sector"]]
print("\nMuestra antes de sectorizar (Genérico / Otros):")
display(before_gen)
print("Misma muestra después de sectorizar:")
display(after_gen)
# Out:
# Filas sectorizadas por categoría adicional:
# - SaaS / Cloud / Plataformas: 0
# - Fintech / Pagos: 0
# - Cripto / Fintech: 0
# - RRSS / Redes Sociales: 0
# - Viajes / Transporte: 0
# - Energía / Seguros: 0
#
# Filas restantes en df_gen (Genérico / Otros): 36
#
# Muestra antes de sectorizar (Genérico / Otros):
#                                                    url  \
# 247  http://webseguridadcuenta-9e626b.ingress-bonde...
# 251  https://suponsoro22-ba9799.ingress-daribow.ewp...
# 252  https://suponsoo22-ba6aa2.ingress-florina.ewp....
# 253  https://supoertas22-bb468f.ingress-bonde.ewp.l...
# 254  https://supanort22-baa4c7.ingress-erytho.ewp.l...
# 261  https://particulares-es-b965d0.ingress-compore...
# 262  https://particulares-es-1-bd5e31.ingress-darib...
# 268  https://informacion-cliente-spainespain3412230...
# 305  https://cuentainformacion-b8eb22.ingress-compo...
# 338  https://confirmacion-cuenta-1-9cd542.ingress-c...
# 343  https://bixtnet-c439fe.ingress-erytho.ewp.live...
# 344  https://appvirtual.cloudbanshag.cloud/verifica...
# 345  https://acceso-ba004e.ingress-baronn.ewp.live/...
# 361  https://2333-b5e370.ingress-earth.ewp.live/acc...
# 362  https://mi-cuenta-informacion-b58175.ingress-b...
# 363  https://clientes-servicio-b9f795.ingress-earth...
# 364  http://alertanotificacionesdinamicos.com/verif...
# 365  https://servicioelportal-particulare-bc8925.in...
# 368                 https://recibo-de-pago.weebly.com/
# 372  https://sites.google.com/view/habilitaciondeac...
#
#                                                 domain   entidad categoria  \
# 247  webseguridadcuenta-9e626b.ingress-bonde.easywp...  Generico       NaN
# 251        suponsoro22-ba9799.ingress-daribow.ewp.live  Generico       NaN
# 252         suponsoo22-ba6aa2.ingress-florina.ewp.live  Generico       NaN
# 253          supoertas22-bb468f.ingress-bonde.ewp.live  Generico       NaN
# 254          supanort22-baa4c7.ingress-erytho.ewp.live  Generico       NaN
# 261  particulares-es-b965d0.ingress-comporellon.ewp...  Generico       NaN
# 262  particulares-es-1-bd5e31.ingress-daribow.ewp.live  Generico       NaN
# 268  informacion-cliente-spainespain34122306.codean...  Generico       NaN
# 305  cuentainformacion-b8eb22.ingress-comporellon.e...  Generico       NaN
# 338  confirmacion-cuenta-1-9cd542.ingress-comporell...  Generico       NaN
# 343             bixtnet-c439fe.ingress-erytho.ewp.live  Generico       NaN
# 344                      appvirtual.cloudbanshag.cloud  Generico       NaN
# 345              acceso-ba004e.ingress-baronn.ewp.live  Generico       NaN
# 361                 2333-b5e370.ingress-earth.ewp.live  Generico       NaN
# 362  mi-cuenta-informacion-b58175.ingress-baronn.ew...  Generico       NaN
# 363    clientes-servicio-b9f795.ingress-earth.ewp.live  Generico       NaN
# 364                  alertanotificacionesdinamicos.com  Generico       NaN
# 365  servicioelportal-particulare-bc8925.ingress-da...  Generico       NaN
# 368                                                NaN       NaN  genérico
# 372                                                NaN       NaN  genérico
#
#                sector
# 247  Genérico / Otros
# 251  Genérico / Otros
# 252  Genérico / Otros
# 253  Genérico / Otros
# 254  Genérico / Otros
# 261  Genérico / Otros
# 262  Genérico / Otros
# 268  Genérico / Otros
# 305  Genérico / Otros
# 338  Genérico / Otros
# 343  Genérico / Otros
# 344  Genérico / Otros
# 345  Genérico / Otros
# 361  Genérico / Otros
# 362  Genérico / Otros
# 363  Genérico / Otros
# 364  Genérico / Otros
# 365  Genérico / Otros
# 368  Genérico / Otros
# 372  Genérico / Otros
# Misma muestra después de sectorizar:
#                                                    url  \
# 247  http://webseguridadcuenta-9e626b.ingress-bonde...
# 251  https://suponsoro22-ba9799.ingress-daribow.ewp...
# 252  https://suponsoo22-ba6aa2.ingress-florina.ewp....
# 253  https://supoertas22-bb468f.ingress-bonde.ewp.l...
# 254  https://supanort22-baa4c7.ingress-erytho.ewp.l...
# 261  https://particulares-es-b965d0.ingress-compore...
# 262  https://particulares-es-1-bd5e31.ingress-darib...
# 268  https://informacion-cliente-spainespain3412230...
# 305  https://cuentainformacion-b8eb22.ingress-compo...
# 338  https://confirmacion-cuenta-1-9cd542.ingress-c...
# 343  https://bixtnet-c439fe.ingress-erytho.ewp.live...
# 344  https://appvirtual.cloudbanshag.cloud/verifica...
# 345  https://acceso-ba004e.ingress-baronn.ewp.live/...
# 361  https://2333-b5e370.ingress-earth.ewp.live/acc...
# 362  https://mi-cuenta-informacion-b58175.ingress-b...
# 363  https://clientes-servicio-b9f795.ingress-earth...
# 364  http://alertanotificacionesdinamicos.com/verif...
# 365  https://servicioelportal-particulare-bc8925.in...
# 368                 https://recibo-de-pago.weebly.com/
# 372  https://sites.google.com/view/habilitaciondeac...
#
#                                                 domain   entidad categoria  \
# 247  webseguridadcuenta-9e626b.ingress-bonde.easywp...  Generico       NaN
# 251        suponsoro22-ba9799.ingress-daribow.ewp.live  Generico       NaN
# 252         suponsoo22-ba6aa2.ingress-florina.ewp.live  Generico       NaN
# 253          supoertas22-bb468f.ingress-bonde.ewp.live  Generico       NaN
# 254          supanort22-baa4c7.ingress-erytho.ewp.live  Generico       NaN
# 261  particulares-es-b965d0.ingress-comporellon.ewp...  Generico       NaN
# 262  particulares-es-1-bd5e31.ingress-daribow.ewp.live  Generico       NaN
# 268  informacion-cliente-spainespain34122306.codean...  Generico       NaN
# 305  cuentainformacion-b8eb22.ingress-comporellon.e...  Generico       NaN
# 338  confirmacion-cuenta-1-9cd542.ingress-comporell...  Generico       NaN
# 343             bixtnet-c439fe.ingress-erytho.ewp.live  Generico       NaN
# 344                      appvirtual.cloudbanshag.cloud  Generico       NaN
# 345              acceso-ba004e.ingress-baronn.ewp.live  Generico       NaN
# 361                 2333-b5e370.ingress-earth.ewp.live  Generico       NaN
# 362  mi-cuenta-informacion-b58175.ingress-baronn.ew...  Generico       NaN
# 363    clientes-servicio-b9f795.ingress-earth.ewp.live  Generico       NaN
# 364                  alertanotificacionesdinamicos.com  Generico       NaN
# 365  servicioelportal-particulare-bc8925.ingress-da...  Generico       NaN
# 368                                                NaN       NaN  genérico
# 372                                                NaN       NaN  genérico
#
#                sector
# 247  Genérico / Otros
# 251  Genérico / Otros
# 252  Genérico / Otros
# 253  Genérico / Otros
# 254  Genérico / Otros
# 261  Genérico / Otros
# 262  Genérico / Otros
# 268  Genérico / Otros
# 305  Genérico / Otros
# 338  Genérico / Otros
# 343  Genérico / Otros
# 344  Genérico / Otros
# 345  Genérico / Otros
# 361  Genérico / Otros
# 362  Genérico / Otros
# 363  Genérico / Otros
# 364  Genérico / Otros
# 365  Genérico / Otros
# 368  Genérico / Otros
# 372  Genérico / Otros

# %%
# Recalcular `domain` desde `url_norm` usando tldextract (nueva celda final)
import tldextract

def _extract_domain_safe(url):
    try:
        if pd.isna(url):
            return ""
        ext = tldextract.extract(str(url))
        return ext.registered_domain or ""
    except Exception:
        return ""

# Recalcular ignorando el dominio previo
df["domain"] = df["url_norm"].apply(_extract_domain_safe)

# Conteo de dominios vacíos
domain_empty_count = int((df["domain"] == "").sum())
print(f"Filas con domain vacío tras recalcular: {domain_empty_count}")

# Mostrar los 20 primeros dominios recalculados
display(df["domain"].head(20))
# Out:
# Filas con domain vacío tras recalcular: 1
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_19853/1885593815.py:9: DeprecationWarning: The 'registered_domain' property is deprecated and will be removed in the next major version. Use 'top_domain_under_public_suffix' instead, which has the same behavior but a more accurate name.
#   return ext.registered_domain or ""
# 0        caixabank.es
# 1         ibercaja.es
# 2           wizink.es
# 3           wizink.es
# 4          cetelem.es
# 5          cetelem.es
# 6          cajamar.es
# 7         ibercaja.es
# 8          cajamar.es
# 9        kutxabank.es
# 10       kutxabank.es
# 11    unicajabanco.es
# 12    unicajabanco.es
# 13    unicajabanco.es
# 14         abanca.com
# 15       kutxabank.es
# 16      myinvestor.es
# 17      myinvestor.es
# 18         correos.es
# 19         correos.es
# Name: domain, dtype: object
