# %%
from features_v2 import extract_features_v2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from features_v2 import extract_features_v2
#
# File ~/Desktop/phishing-detector/scripts/features_v2.py:31
#      27 from math import log2
#      29 import tldextract
# ---> 31 from features_constantes import (
#      32     SUSPICIOUS_TOKENS_WEIGHT,
#      33     FREE_HOSTING,
#      34     FAKE_TLD_TOKENS,
#      35     TOKEN_DENSITY_K,
#      36     TLD_RISK,
#      37     TRUSTED_TOKENS,
#      38 )
#      39 # Lista binaria para suspicious_path_token (extraída del MD)
#      40 SUSPICIOUS_TOKENS = [
#      41     "verificar", "confirmar", "pago", "paquete", "envio", "aduanas",
#      42     "3d", "3dsecure", "sms", "cliente", "acceso"
#      43 ]
#
# ModuleNotFoundError: No module named 'features_constantes'
