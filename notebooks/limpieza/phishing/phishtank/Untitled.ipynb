# %%
import pandas as pd, re
from datetime import datetime
from pathlib import Path

# Ubicación relativa
NB_DIR = Path.cwd()
ROOT = NB_DIR.parents[3]  # phishing-detector/
RAW_PHISHTANK = ROOT / "data/raw/phishing/phishtank/phishtank_01.csv"
OUT_CANDIDATAS = ROOT / "data/processed/phishing/phishtank_candidatas_segunda.csv"

# Cargar PhishTank
pt = pd.read_csv(RAW_PHISHTANK)
pt["url"] = pt["url"].astype(str)

# %%
# Echar un vistazo al dataset crudo de PhishTank
print("Filas:", len(pt))
print("Columnas:", list(pt.columns))

# Primeras filas
pt.head(10)

# Duplicados
dups = pt["url"].duplicated().sum()
print("Duplicados por URL:", dups)

# Valores nulos
nulls = pt.isna().sum()
print("Valores nulos por columna:\n", nulls)
# Out:
# Filas: 51716
# Columnas: ['phish_id', 'url', 'phish_detail_url', 'submission_time', 'verified', 'verification_time', 'online', 'target', 'fecha_hora_recoleccion', 'fuente']
# Duplicados por URL: 14
# Valores nulos por columna:
#  phish_id                  0
# url                       0
# phish_detail_url          0
# submission_time           0
# verified                  0
# verification_time         0
# online                    0
# target                    0
# fecha_hora_recoleccion    0
# fuente                    0
# dtype: int64

# %%
# Eliminar duplicados por URL y resetear índice
pt_clean = pt.drop_duplicates(subset=["url"]).reset_index(drop=True)

print("Antes:", len(pt))
print("Después de eliminar duplicados:", len(pt_clean))

# Comprobar que sigue teniendo las columnas esperadas
print("Columnas:", list(pt_clean.columns))

# Vista rápida de algunas filas
pt_clean.head(10)
# Out:
# Antes: 51716
# Después de eliminar duplicados: 51702
# Columnas: ['phish_id', 'url', 'phish_detail_url', 'submission_time', 'verified', 'verification_time', 'online', 'target', 'fecha_hora_recoleccion', 'fuente']
#    phish_id                                         url  \
# 0   9167131              https://teamvoice.m-pages.com/
# 1   9167130               https://merrimsg.m-pages.com/
# 2   9167129               https://tinkabee.m-pages.com/
# 3   9167128              https://btvoice01.m-pages.com/
# 4   9167127                https://comfirm.m-pages.com/
# 5   9167126              https://birejip47.m-pages.com/
# 6   9167125  https://eu.jotform.com/app/251843061781356
# 7   9167124  https://eu.jotform.com/app/251882591814364
# 8   9167123  https://eu.jotform.com/app/251882925426566
# 9   9167122  https://eu.jotform.com/app/251884095401357
#
#                                     phish_detail_url  \
# 0  http://www.phishtank.com/phish_detail.php?phis...
# 1  http://www.phishtank.com/phish_detail.php?phis...
# 2  http://www.phishtank.com/phish_detail.php?phis...
# 3  http://www.phishtank.com/phish_detail.php?phis...
# 4  http://www.phishtank.com/phish_detail.php?phis...
# 5  http://www.phishtank.com/phish_detail.php?phis...
# 6  http://www.phishtank.com/phish_detail.php?phis...
# 7  http://www.phishtank.com/phish_detail.php?phis...
# 8  http://www.phishtank.com/phish_detail.php?phis...
# 9  http://www.phishtank.com/phish_detail.php?phis...
#
#              submission_time verified          verification_time online  \
# 0  2025-07-28T08:55:52+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 1  2025-07-28T08:55:29+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 2  2025-07-28T08:55:01+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 3  2025-07-28T08:54:38+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 4  2025-07-28T08:54:26+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 5  2025-07-28T08:53:47+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 6  2025-07-28T08:53:42+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 7  2025-07-28T08:53:01+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 8  2025-07-28T08:52:29+00:00      yes  2025-07-28T09:02:54+00:00    yes
# 9  2025-07-28T08:46:34+00:00      yes  2025-07-28T08:52:32+00:00    yes
#
#   target fecha_hora_recoleccion     fuente
# 0  Other    2025-07-28 12:05:48  PhishTank
# 1  Other    2025-07-28 12:05:48  PhishTank
# 2  Other    2025-07-28 12:05:48  PhishTank
# 3  Other    2025-07-28 12:05:48  PhishTank
# 4  Other    2025-07-28 12:05:48  PhishTank
# 5  Other    2025-07-28 12:05:48  PhishTank
# 6  Other    2025-07-28 12:05:48  PhishTank
# 7  Other    2025-07-28 12:05:48  PhishTank
# 8  Other    2025-07-28 12:05:48  PhishTank
# 9  Other    2025-07-28 12:05:48  PhishTank

# %%
from urllib.parse import urlparse, unquote
import unicodedata

# Función para normalizar texto
def norm(text):
    if not isinstance(text, str):
        return ""
    text = unquote(text)
    text = unicodedata.normalize("NFKD", text)
    text = text.encode("ascii", "ignore").decode("utf-8", "ignore")
    return text.lower()

# Aplicar segmentación
pt_clean["domain"] = pt_clean["url"].apply(lambda x: urlparse(x).netloc)
pt_clean["path"] = pt_clean["url"].apply(lambda x: urlparse(x).path)
pt_clean["route"] = pt_clean["url"].apply(lambda x: urlparse(x).netloc + urlparse(x).path)

# Aplicar normalización
pt_clean["domain_norm"] = pt_clean["domain"].apply(norm)
pt_clean["path_norm"] = pt_clean["path"].apply(norm)
pt_clean["route_norm"] = pt_clean["route"].apply(norm)

# %%
# -------------------------------------
# Detección de marcas españolas en la URL (optimizado con regex)
# -------------------------------------
import unicodedata
import re

# Lista de marcas españolas relevantes
marcas_es = [
    "santander", "bbva", "caixabank", "sabadell", "ing", "openbank", "bankinter", "kutxabank",
    "evo banco", "unicaja", "cajamar", "abanca", "ibercaja", "targobank",
    "docusign", "teamviewer", "el corte ingles", "carrefour", "mediamarkt", "pccomponentes",
    "mercadona", "lidl", "aldi", "dia", "alcampo", "eroski", "zara", "pullandbear", "bershka",
    "stradivarius", "oysho", "mango", "desigual", "tous", "loewe", "telepizza", "vips", "ginos",
    "fridays", "100 montaditos", "domino", "mcdonalds", "burger king", "seat", "renault",
    "citroen", "mapfre", "mutua", "linea directa", "endesa", "iberdrola", "naturgy", "repsol",
    "cepsa", "holaluz", "totalenergies", "movistar", "vodafone", "orange", "yoigo", "masmovil",
    "pepephone", "digi", "euskaltel", "dgt", "sepe", "catastro", "agencia tributaria",
    "seguridad social", "inem", "suma", "iberia", "renfe", "melia", "nh hoteles", "iberostar",
    "grupo planeta", "once", "fnac", "casa del libro"
]

# Función para normalizar texto (quitar acentos, pasar a minúsculas, etc.)
def normalizar(texto):
    return unicodedata.normalize('NFKD', texto.lower()).encode('ascii', errors='ignore').decode('utf-8')

# Normalizar lista de marcas
marcas_es_norm = [normalizar(m) for m in marcas_es]

# Compilar patrón regex con todas las marcas escapadas
PATRON_MARCAS_ES = re.compile("|".join(map(re.escape, marcas_es_norm)), re.I)

# Aplicar detección a la columna normalizada
pt_clean["url_norm"] = pt_clean["url"].astype(str).apply(normalizar)
pt_clean["marca_es"] = pt_clean["url_norm"].str.contains(PATRON_MARCAS_ES)

# Visualizar resultados
print("Coincidencias con marcas españolas:", pt_clean["marca_es"].sum())
display(pt_clean[pt_clean["marca_es"]].head(10))
# Out:
# Coincidencias con marcas españolas: 2041
#      phish_id                                                url  \
# 60    9167010              https://halsbenning.de/ionos-rechnung
# 100   9166951       https://resilient-dialects-238242.framer.app
# 154   9166844  https://snjsdiowmeks.salesbread.com/?maintenan...
# 196   9166766  https://swisspass.no-betaling.click/ch/2FA/ind...
# 215   9166746  https://docs.google.com/drawings/d/1a6ZGyT2TzR...
# 216   9166747  https://docs.google.com/drawings/d/1a6ZGyT2TzR...
# 229   9166731  https://uwbezorging.wasmer.app/wp-content/ddh/...
# 231   9166729  http://emergingtechnosoft.com/daimlerobi/dainm...
# 238   9166721  https://haunting-quintessential-script-hyvarna...
# 268   9166690      https://digitzenphluxoria-neurovendotex.shop/
#
#                                       phish_detail_url  \
# 60   http://www.phishtank.com/phish_detail.php?phis...
# 100  http://www.phishtank.com/phish_detail.php?phis...
# 154  http://www.phishtank.com/phish_detail.php?phis...
# 196  http://www.phishtank.com/phish_detail.php?phis...
# 215  http://www.phishtank.com/phish_detail.php?phis...
# 216  http://www.phishtank.com/phish_detail.php?phis...
# 229  http://www.phishtank.com/phish_detail.php?phis...
# 231  http://www.phishtank.com/phish_detail.php?phis...
# 238  http://www.phishtank.com/phish_detail.php?phis...
# 268  http://www.phishtank.com/phish_detail.php?phis...
#
#                submission_time verified          verification_time online  \
# 60   2025-07-28T05:04:17+00:00      yes  2025-07-28T05:12:05+00:00    yes
# 100  2025-07-28T02:51:13+00:00      yes  2025-07-28T03:03:04+00:00    yes
# 154  2025-07-27T19:26:04+00:00      yes  2025-07-27T19:41:43+00:00    yes
# 196  2025-07-27T15:30:10+00:00      yes  2025-07-27T15:51:39+00:00    yes
# 215  2025-07-27T15:28:58+00:00      yes  2025-07-27T15:51:39+00:00    yes
# 216  2025-07-27T15:28:58+00:00      yes  2025-07-27T15:51:39+00:00    yes
# 229  2025-07-27T15:28:08+00:00      yes  2025-07-27T15:51:40+00:00    yes
# 231  2025-07-27T15:27:59+00:00      yes  2025-07-27T15:51:40+00:00    yes
# 238  2025-07-27T15:27:05+00:00      yes  2025-07-27T15:41:55+00:00    yes
# 268  2025-07-27T15:24:55+00:00      yes  2025-07-27T15:41:55+00:00    yes
#
#       target fecha_hora_recoleccion     fuente  ... f_spanish_hints_ext  \
# 60     Other    2025-07-28 12:05:48  PhishTank  ...               False
# 100    Optus    2025-07-28 12:05:48  PhishTank  ...               False
# 154  Comcast    2025-07-28 12:05:48  PhishTank  ...               False
# 196    Other    2025-07-28 12:05:48  PhishTank  ...               False
# 215    Other    2025-07-28 12:05:48  PhishTank  ...               False
# 216    Other    2025-07-28 12:05:48  PhishTank  ...               False
# 229    Other    2025-07-28 12:05:48  PhishTank  ...               False
# 231    Other    2025-07-28 12:05:48  PhishTank  ...               False
# 238    Other    2025-07-28 12:05:48  PhishTank  ...               False
# 268    Other    2025-07-28 12:05:48  PhishTank  ...               False
#
#     f_kw_fraude_urg f_es_tld f_ru_tld f_ru_es_kw f_tld_ruso  \
# 60            False    False    False      False      False
# 100           False    False    False      False      False
# 154           False    False    False      False      False
# 196           False    False    False      False      False
# 215           False    False    False      False      False
# 216           False    False    False      False      False
# 229           False    False    False      False      False
# 231           False    False    False      False      False
# 238           False    False    False      False      False
# 268           False    False    False      False      False
#
#     f_marca_fraude_urg  f_kw_admin_publica  f_tld_es_kw_sospechosa  \
# 60                True               False                   False
# 100               True               False                   False
# 154              False               False                   False
# 196               True               False                   False
# 215               True               False                   False
# 216               True               False                   False
# 229               True               False                   False
# 231               True               False                   False
# 238               True               False                   False
# 268               True               False                   False
#
#      f_kw_banca_extra
# 60              False
# 100             False
# 154             False
# 196             False
# 215             False
# 216             False
# 229             False
# 231             False
# 238             False
# 268             False
#
# [10 rows x 28 columns]

# %%
from collections import Counter

# --- Extraer todas las coincidencias por URL ---
def extraer_marcas(texto):
    return PATRON_MARCAS_ES.findall(texto)

# Lista de todas las marcas encontradas en URLs etiquetadas como marca_es = True
coincidencias = pt_clean.loc[pt_clean["marca_es"], "url_norm"].apply(extraer_marcas)

# Aplanar la lista de listas y contar frecuencias
todas_las_marcas = [marca.lower() for sublista in coincidencias for marca in sublista]
conteo_marcas = Counter(todas_las_marcas)

# Convertir a DataFrame para mostrarlo ordenado
df_marcas = pd.DataFrame(conteo_marcas.items(), columns=["marca_detectada", "frecuencia"]).sort_values(by="frecuencia", ascending=False)

# Mostrar tabla
print(f"Total de URLs con marcas detectadas: {pt_clean['marca_es'].sum()}")
display(df_marcas.head(30))
# Out:
# Total de URLs con marcas detectadas: 2041
#    marca_detectada  frecuencia
# 0              ing        1347
# 1              dia         340
# 6           orange         175
# 3             digi         107
# 7              dgt          72
# 4             once          29
# 2             inem          12
# 12            aldi           9
# 10        docusign           6
# 13            seat           6
# 16            bbva           6
# 19       santander           5
# 8             zara           3
# 11           mango           3
# 15            sepe           3
# 21       carrefour           3
# 5             vips           2
# 14            lidl           2
# 23       mcdonalds           2
# 9           domino           1
# 17       caixabank           1
# 18            suma           1
# 20        vodafone           1
# 22           mutua           1

# %%
pt_clean[["url", "domain", "path", "route", "domain_norm", "route_norm"]].head(5)
# Out:
#                               url                 domain path  \
# 0  https://teamvoice.m-pages.com/  teamvoice.m-pages.com    /
# 1   https://merrimsg.m-pages.com/   merrimsg.m-pages.com    /
# 2   https://tinkabee.m-pages.com/   tinkabee.m-pages.com    /
# 3  https://btvoice01.m-pages.com/  btvoice01.m-pages.com    /
# 4    https://comfirm.m-pages.com/    comfirm.m-pages.com    /
#
#                     route            domain_norm              route_norm
# 0  teamvoice.m-pages.com/  teamvoice.m-pages.com  teamvoice.m-pages.com/
# 1   merrimsg.m-pages.com/   merrimsg.m-pages.com   merrimsg.m-pages.com/
# 2   tinkabee.m-pages.com/   tinkabee.m-pages.com   tinkabee.m-pages.com/
# 3  btvoice01.m-pages.com/  btvoice01.m-pages.com  btvoice01.m-pages.com/
# 4    comfirm.m-pages.com/    comfirm.m-pages.com    comfirm.m-pages.com/

# %%
# === Palabras clave extendidas (fraude + urgencia) ===
KW_FRAUDE_URG_RE = re.compile(
    r"(factura|multa|notificaci[oó]n|aviso|env[ií]o|paquete|entrega|"
    r"declaraci[oó]n|impuestos?|pago|recibo|clientes?|acceso|cuenta|"
    r"seguridad|verificar|iniciar[-_]?sesi[oó]n|bloqueo|restringido|"
    r"confirmaci[oó]n|urgente|intento|actividad|clave|contrase[nñ]a|"
    r"reembolso|suspendid[ao]|mensaje|sms|movimientos?|transacci[oó]n|"
    r"saldo|banca|appmovil|descarga|pin|actualizaci[oó]n|"
    r"confirmar|reanudar|soporte|servicio|bloquead[ao]|restricci[oó]n|"
    r"pagina|bloqueada|suspendida|urgencia|inmediato|"
    r"restringida|problema|incidencia|fallo|inseguro|robo|"
    r"an[oó]malo|fraude|detenido|detenci[oó]n|revisi[oó]n|sospechoso|"
    r"actividad sospechosa|alerta|riesgo|intru|cierre|reclamaci[oó]n|"
    r"atenci[oó]n inmediata|acci[oó]n requerida|"
    r"ha sido suspendid[ao]|cuenta cerrada|cuenta bloqueada)",
    re.I
)

# Aplicar al dataset
pt_clean["f_kw_fraude_urg"] = pt_clean["route_norm"].fillna("").str.contains(KW_FRAUDE_URG_RE)

# Diagnóstico (opcional)
print("Coincidencias con KW fraude/urgencia:", pt_clean["f_kw_fraude_urg"].sum())
# Out:
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_33025/4165985191.py:20: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   pt_clean["f_kw_fraude_urg"] = pt_clean["route_norm"].fillna("").str.contains(KW_FRAUDE_URG_RE)
# Coincidencias con KW fraude/urgencia: 456

# %%
from collections import Counter

# --- Extraer todas las coincidencias por ruta ---
def extraer_keywords(texto):
    return KW_FRAUDE_URG_RE.findall(texto)

# Aplicar sobre las URLs que fueron marcadas como True por el patrón
coincidencias_kw = pt_clean.loc[pt_clean["f_kw_fraude_urg"], "route_norm"].apply(extraer_keywords)

# Aplanar la lista de listas
todas_kw = [kw.lower() for sublista in coincidencias_kw for kw in sublista]

# Contar frecuencia
conteo_kw = Counter(todas_kw)

# Convertir a DataFrame para ordenar y visualizar
df_kw = pd.DataFrame(conteo_kw.items(), columns=["keyword_detectada", "frecuencia"]).sort_values(by="frecuencia", ascending=False)

# Mostrar resultados
print(f"Total de URLs con alguna palabra clave de fraude/urgencia: {pt_clean['f_kw_fraude_urg'].sum()}")
display(df_kw.head(30))
# Out:
# Total de URLs con alguna palabra clave de fraude/urgencia: 456
#    keyword_detectada  frecuencia
# 0                pin          92
# 1                sms          88
# 14            pagina          63
# 8            cliente          33
# 2              banca          32
# 7              aviso          26
# 4           servicio          23
# 3               pago          18
# 10           factura          16
# 9             cuenta          15
# 6            soporte          14
# 17              robo          10
# 27         seguridad           9
# 22             multa           8
# 15           entrega           6
# 19            alerta           6
# 12         confirmar           5
# 18          clientes           4
# 21            acceso           4
# 32      notificacion           2
# 5            paquete           2
# 20       declaracion           2
# 24           mensaje           2
# 28             envio           2
# 31             clave           1
# 30       movimientos           1
# 29         bloqueado           1
# 23         verificar           1
# 26          appmovil           1
# 25     actualizacion           1

# %%
# TLDs típicos de España
TLD_ES = (".es", ".gob.es", ".com.es", ".org.es")

pt_clean["f_es_tld"] = pt_clean["domain_norm"].apply(lambda x: any(x.endswith(tld) for tld in TLD_ES))
print("Con TLD español:", pt_clean["f_es_tld"].sum())
# Ver algunas coincidencias para revisar calidad
display(pt_clean[pt_clean["f_es_tld"] == True][["url", "domain_norm"]].head(10))
# Out:
# Con TLD español: 50
#                                                     url  \
# 1024  http://soporte_ionos.viajoencoche.es/?rid=48Y9hLX
# 1900         https://muuimh.poqjfrm.es/J0bnwVyqR7!7e9O/
# 2575  https://vyy.rqfjspfe.es/N4XPv42MsB@3JqvUh/?=$r...
# 3088        https://u58o.yurgltyju.es/u1TFlAprT4GEiE@/$
# 3703  https://asesoriabarrachina.es/wp-includes/stra...
# 3993  https://todoenxenon.es/docusign/document/docus...
# 4170                      https://directedmein.com.es/v
# 4581               https://walletconnect.com-secure.es/
# 4909         https://ver-sec-auth05a.com.es/3/index.php
# 5463                     https://machintios.com.es/ssa/
#
#                         domain_norm
# 1024  soporte_ionos.viajoencoche.es
# 1900              muuimh.poqjfrm.es
# 2575                vyy.rqfjspfe.es
# 3088              u58o.yurgltyju.es
# 3703          asesoriabarrachina.es
# 3993                 todoenxenon.es
# 4170            directedmein.com.es
# 4581    walletconnect.com-secure.es
# 4909         ver-sec-auth05a.com.es
# 5463              machintios.com.es

# %%
KW_ADMIN_PUBLICA_RE = re.compile(
    r"(dgt|aeat|catastro|sepe|certificado|dni|sede|tramites|"
    r"administracion|gobierno|agenciatributaria|inss|cita previa|justicia|mpt|"
    r"padr[oó]n|ayuntamiento|empadronamiento|"
    r"vida laboral|prestaci[oó]n|jubilaci[oó]n|paro|"
    r"permiso|carn[eé]t|matr[ií]cula|"
    r"reservar|turno|solicitud|"
    r"documentaci[oó]n|formulario|registro|expediente)",
    re.I
)

# Aplicar flag al dataset
pt_clean["f_kw_admin_publica"] = pt_clean["route_norm"].fillna("").str.contains(KW_ADMIN_PUBLICA_RE)

# Diagnóstico general
print("URLs con indicios de administración pública española:", pt_clean["f_kw_admin_publica"].sum())

# ---- Distribución individual de términos ----
from collections import Counter
import unicodedata

# Lista de términos normalizados manualmente (sin regex)
palabras_admin_publica = [
    "dgt", "aeat", "catastro", "sepe", "certificado", "dni", "sede", "tramites",
    "administracion", "gobierno", "agenciatributaria", "inss", "cita previa", "justicia", "mpt",
    "padron", "ayuntamiento", "empadronamiento",
    "vida laboral", "prestacion", "jubilacion", "paro",
    "permiso", "carnet", "matricula",
    "reservar", "turno", "solicitud",
    "documentacion", "formulario", "registro", "expediente"
]

# Función para normalizar textos (igual que en norm)
def normalizar(texto):
    return unicodedata.normalize('NFKD', texto.lower()).encode('ascii', errors='ignore').decode('utf-8')

conteo_admin = Counter()

# Contar cada término individual en route_norm
for palabra in palabras_admin_publica:
    coincidencias = pt_clean["route_norm"].str.contains(palabra, case=False, na=False)
    conteo_admin[palabra] = coincidencias.sum()

# Mostrar resultados
print("\nDistribución de términos de administración pública:")
for palabra, total in conteo_admin.most_common():
    print(f"{palabra}: {total}")
# Out:
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_33025/1720369859.py:13: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   pt_clean["f_kw_admin_publica"] = pt_clean["route_norm"].fillna("").str.contains(KW_ADMIN_PUBLICA_RE)
# URLs con indicios de administración pública española: 146
#
# Distribución de términos de administración pública:
# dgt: 66
# mpt: 39
# dni: 17
# registro: 6
# solicitud: 5
# sede: 4
# sepe: 3
# inss: 3
# certificado: 1
# gobierno: 1
# formulario: 1
# aeat: 0
# catastro: 0
# tramites: 0
# administracion: 0
# agenciatributaria: 0
# cita previa: 0
# justicia: 0
# padron: 0
# ayuntamiento: 0
# empadronamiento: 0
# vida laboral: 0
# prestacion: 0
# jubilacion: 0
# paro: 0
# permiso: 0
# carnet: 0
# matricula: 0
# reservar: 0
# turno: 0
# documentacion: 0
# expediente: 0

# %%
# Muestra de URLs marcadas como administración pública
display(
    pt_clean[pt_clean["f_kw_admin_publica"] == True][["url", "route_norm"]].head(25)
)
# Out:
#                                                      url  \
# 230    https://lufi-dekoracio.hu/wp-adminss/serveletr...
# 897    https://ceresdigital.co/R/1HvxMCWQsmsWrKkRDnSN...
# 952    https://metascoachin.work.gd/ludnibmameremavie...
# 1489                      https://docto-info-compte.com/
# 1490           https://docto-info-compte.com/captcha.php
# 2107                https://dgtt48.lat/yyjxzpjg/e2Walj/7
# 2433   https://regularisation-compte.info/pages/billi...
# 2434   https://regularisation-compte.info/pages/card.php
# 4504      https://www.verfication-compte.com/captcha.php
# 5046                        https://ulys-mon-compte.com/
# 5047                  https://ulys-mon-compte.com/as.php
# 5227   https://compas-city.com/wp-admin/css/colors/mi...
# 6676                 https://securipass-mes-comptes.com/
# 6677        https://securipass-mes-comptes.com/login.php
# 7227   https://oysterhousedesigns.com/wp-admin/SP/kit...
# 8362               https://shawedomaindgtyyy.weebly.com/
# 9788        https://iradgt.com/Alibaba/alibaba/index.php
# 9980   https://docs.google.com/drawings/d/1b5BqS0-HM3...
# 10134                https://ssjsjssedefrfdc.weebly.com/
# 10200                      https://acaccompt.weebly.com/
# 10280  http://certificado.vouserpai.com.br/wp-content...
# 11251                          https://qrco.de/Multa-DGT
# 11253                           https://q-r.to/Multa-DGT
# 11254                         https://l.ead.me/Multa-DGT
# 11800         https://fdudyiiud8pkdgtiqy.weeblysite.com/
#
#                                               route_norm
# 230    lufi-dekoracio.hu/wp-adminss/serveletrsservere...
# 897    ceresdigital.co/r/1hvxmcwqsmswrkkrdnsnlcgldwfb...
# 952    metascoachin.work.gd/ludnibmameremaviemonamour...
# 1489                              docto-info-compte.com/
# 1490                   docto-info-compte.com/captcha.php
# 2107                        dgtt48.lat/yyjxzpjg/e2walj/7
# 2433        regularisation-compte.info/pages/billing.php
# 2434           regularisation-compte.info/pages/card.php
# 4504              www.verfication-compte.com/captcha.php
# 5046                                ulys-mon-compte.com/
# 5047                          ulys-mon-compte.com/as.php
# 5227   compas-city.com/wp-admin/css/colors/midnight/m...
# 6676                         securipass-mes-comptes.com/
# 6677                securipass-mes-comptes.com/login.php
# 7227    oysterhousedesigns.com/wp-admin/sp/kita-new.html
# 8362                       shawedomaindgtyyy.weebly.com/
# 9788                iradgt.com/alibaba/alibaba/index.php
# 9980   docs.google.com/drawings/d/1b5bqs0-hm3e3ladmt8...
# 10134                        ssjsjssedefrfdc.weebly.com/
# 10200                              acaccompt.weebly.com/
# 10280  certificado.vouserpai.com.br/wp-content/plugin...
# 11251                                  qrco.de/multa-dgt
# 11253                                   q-r.to/multa-dgt
# 11254                                 l.ead.me/multa-dgt
# 11800                 fdudyiiud8pkdgtiqy.weeblysite.com/

# %%
KW_ENERGIA_RE = re.compile(
    r"(endesa|iberdrola|naturgy|repsol|cepsa|holaluz|totalenergies|"
    r"energia|electricidad|gas|luz|suministro|corte de luz|factura electrica|"
    r"tarifa|comercializadora|contador|consumo|lectura|distribuidora)",
    re.I
)

# Aplicar al dataset
pt_clean["f_kw_energia"] = pt_clean["route_norm"].fillna("").str.contains(KW_ENERGIA_RE)

# Diagnóstico global
print("URLs con indicios de energía/suministros:", pt_clean["f_kw_energia"].sum())

# --- Análisis de distribución ---
from collections import Counter

palabras_energia = [
    "endesa", "iberdrola", "naturgy", "repsol", "cepsa", "holaluz", "totalenergies",
    "energia", "electricidad", "gas", "luz", "suministro", "corte de luz",
    "factura electrica", "tarifa", "comercializadora", "contador", "consumo", "lectura", "distribuidora"
]

conteo_energia = Counter()

for palabra in palabras_energia:
    coincidencias = pt_clean["route_norm"].str.contains(palabra, case=False, na=False)
    conteo_energia[palabra] = coincidencias.sum()

# Mostrar distribución
print("\nDistribución de términos energéticos detectados:")
for palabra, total in conteo_energia.most_common():
    print(f"{palabra}: {total}")
# Out:
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_33025/3322103093.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   pt_clean["f_kw_energia"] = pt_clean["route_norm"].fillna("").str.contains(KW_ENERGIA_RE)
# URLs con indicios de energía/suministros: 55
#
# Distribución de términos energéticos detectados:
# gas: 32
# luz: 16
# energia: 3
# tarifa: 2
# distribuidora: 2
# endesa: 0
# iberdrola: 0
# naturgy: 0
# repsol: 0
# cepsa: 0
# holaluz: 0
# totalenergies: 0
# electricidad: 0
# suministro: 0
# corte de luz: 0
# factura electrica: 0
# comercializadora: 0
# contador: 0
# consumo: 0
# lectura: 0

# %%
# Lista de columnas de heurística aplicadas (ajústala si has añadido más)
cols_flags = [
    "marca_es", 
    "f_kw_fraude_urg", 
    "f_kw_admin_publica", 
    "f_kw_banca_extra", 
    "f_kw_energia", 
    "f_es_tld"
]

# Asegúrate de que todas las columnas existen
for col in cols_flags:
    if col not in pt_clean.columns:
        pt_clean[col] = False

# Calcular score total
pt_clean["score_total"] = pt_clean[cols_flags].sum(axis=1)

# %%
# Filtrar fuera URLs ya descartadas manualmente o que tienen score 0
candidatas = pt_clean[
    (~pt_clean.get("descartado_manual", False)) & 
    (pt_clean["score_total"] >= 1)
].copy()

print(f"Total candidatas con al menos 1 heurística positiva: {len(candidatas)}")
# Out:
# Total candidatas con al menos 1 heurística positiva: 2723

# %%
# Ordenar para priorizar las más sospechosas
candidatas_sorted = candidatas.sort_values(by="score_total", ascending=False)
candidatas_sorted[["url", "route_norm", "score_total"]].head(25)
# Out:
#                                                      url  \
# 11253                           https://q-r.to/Multa-DGT
# 897    https://ceresdigital.co/R/1HvxMCWQsmsWrKkRDnSN...
# 11251                          https://qrco.de/Multa-DGT
# 11254                         https://l.ead.me/Multa-DGT
# 36996  https://www.gasthof-kolpinghaus.de/wordpress/j...
# 6067   https://distribuidoramaguis.com/js/webmail.aru...
# 13603  https://th80p45y4gdhrtjtyjrtrteygtgretgffdgtr6...
# 20425  https://supercaracol.ar/wp-content/plugins/aki...
# 46626  https://docs.google.com/presentation/d/e/2PACX...
# 12018  https://share-eu1.hsforms.com/21h34fiDGT_qB56m...
# 20552  https://docs.google.com/presentation/d/1d88hLQ...
# 20553  https://docs.google.com/presentation/d/1d88hLQ...
# 33338                  https://helpinghandsadvocacy.org/
# 20391                          https://q-r.to/dgtapremio
# 24237                             https://qrco.de/Dgtes5
# 3980   https://few-piano-rapping.on-fleek.app/iiiiii....
# 3993   https://todoenxenon.es/docusign/document/docus...
# 4000   https://friendly-pegasus-fb6087.netlify.app/cl...
# 24239                              https://q-r.to/Dgtes5
# 8362               https://shawedomaindgtyyy.weebly.com/
# 24240                            https://l.ead.me/Dgtes5
# 20394                        https://l.ead.me/dgtapremio
# 22010                          http://cn83141.tw1.ru/DGT
# 20388                         https://qrco.de/dgtapremio
# 6072                   https://cttexpresso-entregas.com/
#
#                                               route_norm  score_total
# 11253                                   q-r.to/multa-dgt            3
# 897    ceresdigital.co/r/1hvxmcwqsmswrkkrdnsnlcgldwfb...            3
# 11251                                  qrco.de/multa-dgt            3
# 11254                                 l.ead.me/multa-dgt            3
# 36996  www.gasthof-kolpinghaus.de/wordpress/js/jatman...            3
# 6067   distribuidoramaguis.com/js/webmail.aruba.it/us...            2
# 13603  th80p45y4gdhrtjtyjrtrteygtgretgffdgtr67grttggt...            2
# 20425  supercaracol.ar/wp-content/plugins/akismet/dgt...            2
# 46626  docs.google.com/presentation/d/e/2pacx-1vtn0gf...            2
# 12018  share-eu1.hsforms.com/21h34fidgt_qb56m4xowj_w2...            2
# 20552  docs.google.com/presentation/d/1d88hlqihlnypih...            2
# 20553  docs.google.com/presentation/d/1d88hlqihlnypih...            2
# 33338                          helpinghandsadvocacy.org/            2
# 20391                                  q-r.to/dgtapremio            2
# 24237                                     qrco.de/dgtes5            2
# 3980          few-piano-rapping.on-fleek.app/iiiiii.html            2
# 3993   todoenxenon.es/docusign/document/docusign-cont...            2
# 4000   friendly-pegasus-fb6087.netlify.app/clientemai...            2
# 24239                                      q-r.to/dgtes5            2
# 8362                       shawedomaindgtyyy.weebly.com/            2
# 24240                                    l.ead.me/dgtes5            2
# 20394                                l.ead.me/dgtapremio            2
# 22010                                 cn83141.tw1.ru/dgt            2
# 20388                                 qrco.de/dgtapremio            2
# 6072                           cttexpresso-entregas.com/            2

# %%
# Guardar el CSV de revisión manual (en tu ruta de processed)
candidatas_sorted.to_csv(OUT_CANDIDATAS, index=False)
print(f"Guardado CSV con {len(candidatas_sorted)} URLs candidatas en: {OUT_CANDIDATAS}")
# Out:
# Guardado CSV con 2723 URLs candidatas en: /Users/test/Desktop/phishing-detector/data/processed/phishing/phishtank_candidatas_segunda.csv
