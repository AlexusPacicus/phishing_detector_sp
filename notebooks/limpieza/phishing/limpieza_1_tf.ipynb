# %%
# === CELDA 1 ===
"""
Notebook: limpieza_tweetfeed.ipynb

Objetivo:
Este notebook realiza la limpieza final del dataset filtrado de Tweetfeed, aplicando revisión manual
y reglas adicionales para eliminar falsos positivos que hayan superado el score heurístico.

Dataset base: tweetfeed_filtradas.csv (2080 URLs con score_total >= 2)
Ubicación: data/processed/phishing/tweetfeed_filtradas.csv
"""
# Out:
# '\nNotebook: limpieza_tweetfeed.ipynb\n\nObjetivo:\nEste notebook realiza la limpieza final del dataset filtrado de Tweetfeed, aplicando revisión manual\ny reglas adicionales para eliminar falsos positivos que hayan superado el score heurístico.\n\nDataset base: tweetfeed_filtradas.csv (2080 URLs con score_total >= 2)\nUbicación: data/processed/phishing/tweetfeed_filtradas.csv\n'

# %%
# === CELDA 1 (Limpieza Final) ===
# Cargamos el CSV previamente filtrado por score_total >= 2

import pandas as pd

file_path_final = "../../../data/processed/phishing/tweetfeed_filtradas.csv"
df_final = pd.read_csv(file_path_final)

print("URLs cargadas para limpieza manual:", len(df_final))
df_final.head(5)
# Out:
# URLs cargadas para limpieza manual: 2080
#                  fecha          autor tipo  \
# 0  2024-12-21 16:34:09  Phish_Destroy  url
# 1  2024-12-21 17:25:12  Phish_Destroy  url
# 2  2024-12-21 17:30:45  Phish_Destroy  url
# 3  2024-12-21 22:34:29  Phish_Destroy  url
# 4  2024-12-21 23:00:07     urldna_bot  url
#
#                                              valor             tags  \
# 0      https://www.blockchainsigns.io.defiswaps.io        #phishing
# 1                       https://signup-fluence.com        #phishing
# 2          https://allocations-wisemonky.pages.dev        #phishing
# 3                    https://steamcommunity-ua.com        #phishing
# 4  https://pop.spotifycloning1.freewebhostmost.com  #scam #phishing
#
#                                         tweet_origen  \
# 0  https://x.com/Phish_Destroy/status/18705080631...
# 1  https://x.com/Phish_Destroy/status/18705209123...
# 2  https://x.com/Phish_Destroy/status/18705223072...
# 3  https://x.com/Phish_Destroy/status/18705987468...
# 4  https://x.com/urldna_bot/status/18706051972836...
#
#                                       host matched_target categoria  \
# 0      www.blockchainsigns.io.defiswaps.io            NaN       NaN
# 1                       signup-fluence.com            NaN       NaN
# 2          allocations-wisemonky.pages.dev           Wise       NaN
# 3                    steamcommunity-ua.com          Steam       NaN
# 4  pop.spotifycloning1.freewebhostmost.com        Spotify       NaN
#
#              registrable  ... s_kw_es f_kw_es s_urgente  f_urgente  \
# 0           defiswaps.io  ...       0   False         0      False
# 1     signup-fluence.com  ...       0   False         0      False
# 2              pages.dev  ...       0   False         0      False
# 3  steamcommunity-ua.com  ...       0   False         0      False
# 4    freewebhostmost.com  ...       0   False         0      False
#
#   s_idioma_extranjero  f_idioma_extranjero  s_marca_mal  marca_detectada_mal  \
# 0                   0                False            2                  ing
# 1                   0                False            2                  ing
# 2                   0                False            0                  NaN
# 3                   0                False            0                  NaN
# 4                   0                False            0                  NaN
#
#    f_marca_mal  score_total
# 0         True            2
# 1         True            2
# 2        False            2
# 3        False            2
# 4        False            2
#
# [5 rows x 29 columns]

# %%
# === CELDA 3 ===
# Contamos los dominios base más frecuentes para identificar campañas repetidas o generadores automáticos

top_registrables = df_final["registrable"].value_counts().head(30)
print("Top 30 dominios base (registrables):")
display(top_registrables)
# Out:
# Top 30 dominios base (registrables):
# registrable
# webflow.io                     93
# vercel.app                     84
# pages.dev                      79
# github.io                      76
# godaddysites.com               25
# amazonaws.com                  18
# azurewebsites.net              14
# web.app                        14
# coinbasewalletrectify.com      13
# coinbaseoption.top             11
# netlify.app                     9
# coinbasesecure-helpdesk.com     8
# googleapis.com                  8
# weebly.com                      8
# ubpages.com                     7
# coinbasewallet.chat             5
# login-coinbase-secured.com      5
# glitch.me                       4
# tiktokga.shop                   4
# yield-coinbase.com              4
# auth-coinbase-trust.com         4
# coinbasepay.xyz                 3
# qkipikpp.es                     3
# 8331202-coinbase.com            3
# xw0s5cxu2o60ng.xyz              3
# coinbase.tools                  3
# coinbaseindexfund.com           3
# wixsite.com                     3
# firebaseapp.com                 3
# workers.dev                     3
# Name: count, dtype: int64

# %%
# === CELDA 6 ===
# Lista personalizada de dominios que vas a eliminar por ser baratos/sospechosos
dominios_a_eliminar = [
    "webflow.io", "vercel.app", "pages.dev", "github.io", "godaddysites.com",
    "netlify.app", "glitch.me", "weebly.com", "firebaseapp.com", "workers.dev",
    "wixsite.com", "web.app", "ubpages.com", "azurewebsites.net"
]

# Marcamos con una nueva columna booleana
df_final["f_dominio_barato"] = df_final["registrable"].isin(dominios_a_eliminar)

# Conteo de URLs marcadas
print("URLs marcadas para eliminación (dominios baratos):", df_final["f_dominio_barato"].sum())

# Eliminamos del DataFrame
df_final = df_final[df_final["f_dominio_barato"] == False].copy()
print("Total restante tras limpieza:", len(df_final))
# Out:
# URLs marcadas para eliminación (dominios baratos): 422
# Total restante tras limpieza: 1658

# %%
# === CELDA 7 ===
# Contamos las marcas detectadas más frecuentes tras limpieza de dominios baratos
print("Top 20 marcas tras limpieza:")
df_final["brand"].value_counts(dropna=True).head(20)
# Out:
# Top 20 marcas tras limpieza:
# brand
# coinbase            568
# digi                191
# amazon              127
# hbo                  78
# steam                60
# binance              52
# kraken               51
# visa                 38
# ups                  30
# mastercard           26
# dhl                  16
# tiktok               15
# spotify              14
# paypal               14
# american express     11
# wise                 10
# zoom                  9
# facebook              8
# inem                  7
# linkedin              7
# Name: count, dtype: int64

# %%
# === CELDA 8 ===
# Cambia "coinbase" por la marca que quieras revisar

marca_objetivo = "inem"

ejemplos_marca = df_final[df_final["brand"] == marca_objetivo][
    ["valor", "host", "path", "matched_target", "categoria", "score_total"]
].head(50)

print(f"Ejemplos para la marca: {marca_objetivo}")
display(ejemplos_marca)
# Out:
# Ejemplos para la marca: inem
#                                                  valor  \
# 799   https://vieuvenocrac.eminemlakuskudar.com/resona
# 944                https://gothammachinemadecigars.com
# 973                 https://carolineminingplatform.com
# 1043                             https://finememe.site
# 1119                         https://m.rainempower.com
# 1476                 http://msonlinemailencryption.com
# 1637                 https://inlinemarketingmedia.hair
#
#                                    host     path matched_target categoria  \
# 799   vieuvenocrac.eminemlakuskudar.com  /resona           INEM       NaN
# 944         gothammachinemadecigars.com        /           INEM       NaN
# 973          carolineminingplatform.com        /           INEM       NaN
# 1043                      finememe.site        /           INEM       NaN
# 1119                  m.rainempower.com        /           INEM       NaN
# 1476         msonlinemailencryption.com        /           INEM       NaN
# 1637          inlinemarketingmedia.hair        /           INEM       NaN
#
#       score_total
# 799             2
# 944             2
# 973             2
# 1043            2
# 1119            2
# 1476            2
# 1637            2

# %%
# === CELDA 9 ===
# Filtramos solo las URLs cuyo host contiene ".es" o termina en ".es"

df_es = df_final[df_final["host"].str.contains(r"\.es\b", case=False, na=False)].copy()

print("URLs que contienen '.es' en el dominio:", len(df_es))
df_es[["valor", "host", "brand", "score_total"]].head(31)
# Out:
# URLs que contienen '.es' en el dominio: 31
#                                                   valor  \
# 22                               https://robllox.com.es
# 38                                   https://rivers2.es
# 103                              https://uniwescouni.es
# 104                            https://wunivescovwes.es
# 110   https://gellyte.es/1adabd9b-6e58-4a7e-bbd8-c65...
# 178   https://zooominvitenotice.es/project/Windows/i...
# 181      https://gnorizete-tonpelati.es/default.php?id=
# 218                               https://robiox.com.es
# 600                    https://coinbasewalletsupport.es
# 626                              https://gettrumpmem.es
# 683   http://unicismadrid.es/wp-content/com/index/ch...
# 882   https://authline-checkappr0v.com.es/7aIT03j82s...
# 1425              https://aruba.it-fattura.es/Pagamento
# 1458                           https://koinbay-login.es
# 1462         http://secretosbp.es/DROPBOX/DROPBOX/vinc/
# 1549           https://boxperience.es/cuenta/es-ing/ing
# 1620                 http://authline-checkappr0v.com.es
# 1621                    http://serv-authveriline.com.es
# 1622                              http://ld4.gkgqfod.es
# 1623                             http://efb0o.dfahpt.es
# 1702         http://yzpje.mlcezlifekc.es/KeSRE6pBrWP3@Z
# 1746                    https://mundogluck.avantecds.es
# 1783  http://bczav-resource-innovationss.qkipikpp.es...
# 1789               https://g9q.zwyvcm.es/MTPXp4nJOtL@R/
# 1793                             https://greencolors.es
# 1802  http://bdwfge.mdtfi.es/WC!2eXtGKBvNsd/$fritz.w...
# 1805  http://bixyc-cmscorp.qkipikpp.es/nc@y5xfx5snpz...
# 1832  http://gt0ll-mtechg.qkipikpp.es/ok1wcgx6w!ghnr...
# 1848  http://1wncv.vfaotwv.es/9@g2K21hcRdiS/$YXBAc2x...
# 1929  https://asesoriabarrachina.es/wp-includes/stra...
# 1969                             https://nexoconnect.es
#
#                                          host     brand  score_total
# 22                             robllox.com.es       NaN            2
# 38                                 rivers2.es       NaN            2
# 103                            uniwescouni.es       NaN            2
# 104                          wunivescovwes.es       NaN            2
# 110                                gellyte.es       NaN            2
# 178                      zooominvitenotice.es       NaN            2
# 181                    gnorizete-tonpelati.es       NaN            2
# 218                             robiox.com.es       NaN            2
# 600                  coinbasewalletsupport.es  coinbase            4
# 626                            gettrumpmem.es       NaN            2
# 683                           unicismadrid.es       NaN            2
# 882               authline-checkappr0v.com.es       NaN            2
# 1425                      aruba.it-fattura.es       NaN            2
# 1458                         koinbay-login.es       NaN            2
# 1462                            secretosbp.es   dropbox            4
# 1549                           boxperience.es       NaN            4
# 1620              authline-checkappr0v.com.es       NaN            2
# 1621                 serv-authveriline.com.es       NaN            2
# 1622                           ld4.gkgqfod.es       NaN            2
# 1623                          efb0o.dfahpt.es       NaN            2
# 1702                     yzpje.mlcezlifekc.es       NaN            2
# 1746                  mundogluck.avantecds.es       NaN            2
# 1783  bczav-resource-innovationss.qkipikpp.es       NaN            2
# 1789                            g9q.zwyvcm.es       NaN            2
# 1793                           greencolors.es       NaN            2
# 1802                          bdwfge.mdtfi.es       NaN            2
# 1805                bixyc-cmscorp.qkipikpp.es       NaN            2
# 1832                 gt0ll-mtechg.qkipikpp.es       NaN            2
# 1848                         1wncv.vfaotwv.es       NaN            2
# 1929                    asesoriabarrachina.es       NaN            2
# 1969                           nexoconnect.es       NaN            2

# %%
# === CELDA 10 ===
# Marcamos URLs que:
# - tienen .es en el host
# - pero no se ha detectado ninguna marca ('brand' está vacío o NaN)

df_final["f_es_sin_marca"] = (
    df_final["host"].str.contains(r"\.es\b", case=False, na=False) &
    (df_final["brand"].isna() | (df_final["brand"] == ""))
)

print("URLs con .es pero sin marca detectada:", df_final["f_es_sin_marca"].sum())

# Vista rápida de ejemplos
df_final[df_final["f_es_sin_marca"] == True][["valor", "host", "path", "score_total"]].head(29)
# Out:
# URLs con .es pero sin marca detectada: 29
#                                                   valor  \
# 22                               https://robllox.com.es
# 38                                   https://rivers2.es
# 103                              https://uniwescouni.es
# 104                            https://wunivescovwes.es
# 110   https://gellyte.es/1adabd9b-6e58-4a7e-bbd8-c65...
# 178   https://zooominvitenotice.es/project/Windows/i...
# 181      https://gnorizete-tonpelati.es/default.php?id=
# 218                               https://robiox.com.es
# 626                              https://gettrumpmem.es
# 683   http://unicismadrid.es/wp-content/com/index/ch...
# 882   https://authline-checkappr0v.com.es/7aIT03j82s...
# 1425              https://aruba.it-fattura.es/Pagamento
# 1458                           https://koinbay-login.es
# 1549           https://boxperience.es/cuenta/es-ing/ing
# 1620                 http://authline-checkappr0v.com.es
# 1621                    http://serv-authveriline.com.es
# 1622                              http://ld4.gkgqfod.es
# 1623                             http://efb0o.dfahpt.es
# 1702         http://yzpje.mlcezlifekc.es/KeSRE6pBrWP3@Z
# 1746                    https://mundogluck.avantecds.es
# 1783  http://bczav-resource-innovationss.qkipikpp.es...
# 1789               https://g9q.zwyvcm.es/MTPXp4nJOtL@R/
# 1793                             https://greencolors.es
# 1802  http://bdwfge.mdtfi.es/WC!2eXtGKBvNsd/$fritz.w...
# 1805  http://bixyc-cmscorp.qkipikpp.es/nc@y5xfx5snpz...
# 1832  http://gt0ll-mtechg.qkipikpp.es/ok1wcgx6w!ghnr...
# 1848  http://1wncv.vfaotwv.es/9@g2K21hcRdiS/$YXBAc2x...
# 1929  https://asesoriabarrachina.es/wp-includes/stra...
# 1969                             https://nexoconnect.es
#
#                                          host  \
# 22                             robllox.com.es
# 38                                 rivers2.es
# 103                            uniwescouni.es
# 104                          wunivescovwes.es
# 110                                gellyte.es
# 178                      zooominvitenotice.es
# 181                    gnorizete-tonpelati.es
# 218                             robiox.com.es
# 626                            gettrumpmem.es
# 683                           unicismadrid.es
# 882               authline-checkappr0v.com.es
# 1425                      aruba.it-fattura.es
# 1458                         koinbay-login.es
# 1549                           boxperience.es
# 1620              authline-checkappr0v.com.es
# 1621                 serv-authveriline.com.es
# 1622                           ld4.gkgqfod.es
# 1623                          efb0o.dfahpt.es
# 1702                     yzpje.mlcezlifekc.es
# 1746                  mundogluck.avantecds.es
# 1783  bczav-resource-innovationss.qkipikpp.es
# 1789                            g9q.zwyvcm.es
# 1793                           greencolors.es
# 1802                          bdwfge.mdtfi.es
# 1805                bixyc-cmscorp.qkipikpp.es
# 1832                 gt0ll-mtechg.qkipikpp.es
# 1848                         1wncv.vfaotwv.es
# 1929                    asesoriabarrachina.es
# 1969                           nexoconnect.es
#
#                                                    path  score_total
# 22                                                    /            2
# 38                                                    /            2
# 103                                                   /            2
# 104                                                   /            2
# 110     /1adabd9b-6e58-4a7e-bbd8-c65bab532ad8/3mail@b.c            2
# 178                         /project/Windows/invite.php            2
# 181                                        /default.php            2
# 218                                                   /            2
# 626                                                   /            2
# 683                 /wp-content/com/index/ch/login.html            2
# 882   /7aIT03j82stf28&sp_aqd=d2lkZ264DGsrFT5vGFGhuTr...            2
# 1425                                         /Pagamento            2
# 1458                                                  /            2
# 1549                                 /cuenta/es-ing/ing            4
# 1620                                                  /            2
# 1621                                                  /            2
# 1622                                                  /            2
# 1623                                                  /            2
# 1702                                    /KeSRE6pBrWP3@Z            2
# 1746                                                  /            2
# 1783                                  /Ok1WCgX6w!gHNR/*            2
# 1789                                    /MTPXp4nJOtL@R/            2
# 1793                                                  /            2
# 1802        /WC!2eXtGKBvNsd/$fritz.wagner@slurpmail.net            2
# 1805     /nc@y5xfx5snpzbu/*zgrhcnjhz2hay21zy29ycc5jb20=            2
# 1832      /ok1wcgx6w!ghnr/*y3jvzhjpz3vlekbtdgvjagcuy29t            2
# 1848           /9@g2K21hcRdiS/$YXBAc2x1cnBtYWlsLm5ldA==            2
# 1929                               /wp-includes/strato/            2
# 1969                                                  /            2

# %%
# === CELDA 11 (versión PhishTank compatible) ===
# Preparamos un CSV con estructura igual a phishtank_clean.csv

df_es_export = df_final[df_final["f_es_sin_marca"] == True].copy()

df_export = pd.DataFrame({
    "url": df_es_export["valor"],
    "matched_target": df_es_export["brand"].fillna(""),
    "fecha_hora_recoleccion": df_es_export["fecha"],
    "fuente": "tweetfeed",
    "categoria": "",
    "notas": ""  # Aquí marcarás a mano "falso positivo" o lo que necesites
})

output_path = "../../../data/processed/tweetfeed_es_revision_phishtank_format.csv"
df_export.to_csv(output_path, index=False)

print("CSV para revisión manual generado en:", output_path)
print("Total de URLs a revisar:", len(df_export))
# Out:
# CSV para revisión manual generado en: ../../../data/processed/tweetfeed_es_revision_phishtank_format.csv
# Total de URLs a revisar: 29

# %%
# === CELDA: Eliminar 29 URLs revisadas del df_final ===
import pandas as pd

# Cargar las 29 URLs desde tu CSV de revisión manual
df_revisadas = pd.read_csv("../../../data/processed/phishing/tweetfeed_es_sin_marca_para_revision.csv")

# Solo las primeras 29 filas (las revisadas a mano)
urls_revisadas = set(df_revisadas["valor"].astype(str).head(29).str.strip())

# Eliminar del dataframe que ya usaste en CELDA 6
print("Antes de eliminar:", len(df_final))
df_final = df_final[~df_final["valor"].astype(str).isin(urls_revisadas)].copy()
print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1658
# Después de eliminar: 1629

# %%
# === CELDA: Top marcas tras limpieza de dominios y URLs revisadas ===
top_brands = df_final["brand"].value_counts(dropna=True).head(30)

print("Top 20 marcas restantes:")
display(top_brands)
# Out:
# Top 20 marcas restantes:
# brand
# coinbase            568
# digi                191
# amazon              127
# hbo                  78
# steam                60
# binance              52
# kraken               51
# visa                 38
# ups                  30
# mastercard           26
# dhl                  16
# tiktok               15
# spotify              14
# paypal               14
# american express     11
# wise                 10
# zoom                  9
# facebook              8
# inem                  7
# linkedin              7
# instagram             6
# movistar              6
# netflix               5
# bit2me                5
# orange                4
# gls                   4
# nike                  3
# adidas                3
# snapchat              3
# ebay                  3
# Name: count, dtype: int64

# %%
# === CELDA: Buscar menciones de empresas españolas relevantes ===

marcas_es = [
    "bbva", "santander", "caixabank", "bankinter", "unicaja", "sabadell", "abanca", "kutxabank",
    "digi", "movistar", "masmovil", "vodafone", "orange", "telefonica",
    "correos", "inem", "seg-social", "seguridadsocial", "dgt", "agenciatributaria",
    "iberdrola", "endesa", "naturgy", "repsol"
]

# Unimos host + path, normalizados
df_final["host_path_norm"] = (df_final["host"].fillna("") + " " + df_final["path"].fillna("")).str.lower()

# Filtramos si aparece alguna marca en host o path
pattern = "|".join(marcas_es)
df_empresas_es = df_final[df_final["host_path_norm"].str.contains(pattern)].copy()

print("Total URLs con marcas españolas detectadas en host o path:", len(df_empresas_es))
df_empresas_es[["valor", "host", "path", "score_total"]].head(59)
# Out:
# Total URLs con marcas españolas detectadas en host o path: 218
#                                                  valor  \
# 5                              https://digitalweb.live
# 6                             https://digitalmintx.com
# 8                             https://luandigital.site
# 12                           https://digitalborger.com
# 17                            https://liquidus.digital
# 24                            https://velvetdigits.com
# 27                     http://qfast.duckdns.org/bbva5/
# 29                      https://bifrostwebdapp.digital
# 35                        https://sparkdaosflr.digital
# 57                 https://digital-blastfoundation.com
# 60                        https://gam3s-v2-app.digital
# 62             https://wallstreetpepe.velvetdigits.com
# 63                         https://digitalwebchain.xyz
# 77                            https://apps-web.digital
# 81                               https://gauge.digital
# 82                             https://loomlay.digital
# 83                      https://reward-glacier.digital
# 84                      https://stake-altlayer.digital
# 85                           https://wallchain.digital
# 97                               https://digihparm.com
# 98                          https://app-aipump.digital
# 118  https://service.santander.de/webapps/apps/zust...
# 150                         https://loomlaysol.digital
# 152                     https://immortalrising.digital
# 153                  https://legends-mintchain.digital
# 154                             https://ubitex.digital
# 155                         https://marsisfine.digital
# 156                        https://stake-stone.digital
# 163                          https://digitalbitbox.com
# 173                          https://digitpotalent.com
# 176                   https://blast-easy-digital.world
# 179           https://app-parasvvap.network-v2.digital
# 189                          https://ethdenver.digital
# 191                          https://flaredigitals.net
# 195                    http://vodafone.accept-term.com
# 201                           https://sonicweb.digital
# 202                    https://bridges-swipers.digital
# 217                     https://airdrop-derive.digital
# 219          https://ruuokeiedehuazhu.websitedigit.com
# 220           http://ruuokeiedehuazhu.websitedigit.com
# 223                        https://swap.digi-pharm.pro
# 228                             https://bxlabs.digital
# 229                          https://get-lotus.digital
# 237           https://aviso-caixa.digital/inicio/enter
# 247                            https://depinai.digital
# 255                              https://yeorn.digital
# 281                  https://partyiconspayment.digital
# 298                    https://flaredigitalnetwork.net
# 311                            https://mysonic.digital
# 313                     https://orbiterfinance.digital
# 323                        http://depinaitoken.digital
# 335                           https://digitptalent.com
# 345                     https://247premierdigitals.com
# 369           https://walletconnect.digitradegroup.com
# 372                            https://kelpdigital.xyz
# 377                           https://notpixel.digital
# 378                          https://nft.digitoads.net
# 380                       https://sui-platform.digital
# 383      https://tech.corredigitalapi.com/connect.html
#
#                                   host                       path  score_total
# 5                      digitalweb.live                          /            2
# 6                     digitalmintx.com                          /            2
# 8                     luandigital.site                          /            2
# 12                   digitalborger.com                          /            2
# 17                    liquidus.digital                          /            2
# 24                    velvetdigits.com                          /            2
# 27                   qfast.duckdns.org                    /bbva5/            2
# 29              bifrostwebdapp.digital                          /            2
# 35                sparkdaosflr.digital                          /            2
# 57         digital-blastfoundation.com                          /            2
# 60                gam3s-v2-app.digital                          /            2
# 62     wallstreetpepe.velvetdigits.com                          /            2
# 63                 digitalwebchain.xyz                          /            2
# 77                    apps-web.digital                          /            2
# 81                       gauge.digital                          /            2
# 82                     loomlay.digital                          /            2
# 83              reward-glacier.digital                          /            2
# 84              stake-altlayer.digital                          /            2
# 85                   wallchain.digital                          /            2
# 97                       digihparm.com                          /            2
# 98                  app-aipump.digital                          /            2
# 118               service.santander.de  /webapps/apps/zustimmung/            2
# 150                 loomlaysol.digital                          /            2
# 152             immortalrising.digital                          /            2
# 153          legends-mintchain.digital                          /            2
# 154                     ubitex.digital                          /            2
# 155                 marsisfine.digital                          /            2
# 156                stake-stone.digital                          /            2
# 163                  digitalbitbox.com                          /            2
# 173                  digitpotalent.com                          /            2
# 176           blast-easy-digital.world                          /            2
# 179   app-parasvvap.network-v2.digital                          /            2
# 189                  ethdenver.digital                          /            2
# 191                  flaredigitals.net                          /            2
# 195           vodafone.accept-term.com                          /            4
# 201                   sonicweb.digital                          /            2
# 202            bridges-swipers.digital                          /            2
# 217             airdrop-derive.digital                          /            2
# 219  ruuokeiedehuazhu.websitedigit.com                          /            2
# 220  ruuokeiedehuazhu.websitedigit.com                          /            2
# 223                swap.digi-pharm.pro                          /            2
# 228                     bxlabs.digital                          /            2
# 229                  get-lotus.digital                          /            2
# 237                aviso-caixa.digital              /inicio/enter            2
# 247                    depinai.digital                          /            2
# 255                      yeorn.digital                          /            2
# 281          partyiconspayment.digital                          /            2
# 298            flaredigitalnetwork.net                          /            2
# 311                    mysonic.digital                          /            2
# 313             orbiterfinance.digital                          /            2
# 323               depinaitoken.digital                          /            2
# 335                   digitptalent.com                          /            2
# 345             247premierdigitals.com                          /            2
# 369   walletconnect.digitradegroup.com                          /            2
# 372                    kelpdigital.xyz                          /            2
# 377                   notpixel.digital                          /            2
# 378                  nft.digitoads.net                          /            2
# 380               sui-platform.digital                          /            2
# 383           tech.corredigitalapi.com              /connect.html            2

# %%
# === CELDA: Helper para mostrar subset con columnas útiles CSV ===
def vista_csv(df, fuente="tweetfeed", categoria=""):
    cols = {
        "url": df.get("valor", pd.Series(dtype=str)),
        "matched_target": df.get("matched_target", pd.Series(dtype=str)).fillna(""),
        "fecha_hora_recoleccion": df.get("fecha", pd.Series(dtype=str)),
        "fuente": fuente,
        "categoria": categoria,
        "notas": ""  # para marcar a mano después ("idioma_es", "manual_ok"...)
    }
    df_vista = pd.DataFrame(cols)
    return df_vista

# %%
# === CELDA: Eliminar directamente las URLs de df_empresas_es ===

print("Antes de eliminar:", len(df_final))

df_final = df_final[~df_final["valor"].isin(df_empresas_es["valor"])].copy()

print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1629
# Después de eliminar: 1411

# %%
df_es_reg = df_final[df_final["registrable"].str.endswith(".es", na=False)]

# %%
df_es_reg.head(20)
# Out:
#                     fecha          autor tipo  \
# 600   2025-02-11 17:57:36  Phish_Destroy  url
# 1462  2025-04-13 14:39:28     skocherhan  url
#
#                                            valor       tags  \
# 600             https://coinbasewalletsupport.es  #phishing
# 1462  http://secretosbp.es/DROPBOX/DROPBOX/vinc/  #phishing
#
#                                            tweet_origen  \
# 600   https://x.com/Phish_Destroy/status/18893732341...
# 1462  https://x.com/skocherhan/status/19114290304877...
#
#                           host matched_target categoria  \
# 600   coinbasewalletsupport.es       Coinbase       NaN
# 1462             secretosbp.es        Dropbox       NaN
#
#                    registrable  ... s_marca_mal marca_detectada_mal  \
# 600   coinbasewalletsupport.es  ...           0                 NaN
# 1462             secretosbp.es  ...           0                 NaN
#
#      f_marca_mal  score_total               path_norm  f_path_generica  \
# 600        False            4                       /             True
# 1462       False            4  /dropbox/dropbox/vinc/            False
#
#       f_dominio_barato  f_es_sin_marca                 host_norm  \
# 600              False           False  coinbasewalletsupport.es
# 1462             False           False             secretosbp.es
#
#                             host_path_norm
# 600             coinbasewalletsupport.es /
# 1462  secretosbp.es /dropbox/dropbox/vinc/
#
# [2 rows x 35 columns]

# %%
urls_revisadas = {
    "https://coinbasewalletsupport.es",
    "http://secretosbp.es/DROPBOX/DROPBOX/vinc/"
}

print("Antes de eliminar:", len(df_final))

df_final = df_final[~df_final["valor"].isin(urls_revisadas)].copy()

print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1411
# Después de eliminar: 1409

# %%
# === CELDA: Buscar pistas de idioma español en URL (vista con TODAS las columnas) ===
import re

# 1) Query params
LANG_ES_QUERY = re.compile(r"(lang|locale|hl|ln|idioma|language)(=|%3D)(es|es[-_]?es|sp)", re.I)
mask_query = df_final["valor"].str.contains(LANG_ES_QUERY, na=False)

# 2) Rutas
LANG_ES_PATH = re.compile(r"(^|/)(es|es[-_](es|mx|ar|cl|co|pe))(/|$)", re.I)
mask_path = df_final["path"].fillna("").str.contains(LANG_ES_PATH, na=False)

# 3) Subdominio
mask_sub = df_final["host"].fillna("").str.startswith("es.", na=False)

# Combina todo
mask_lang_es = mask_query | mask_path | mask_sub

df_lang_es = df_final[mask_lang_es].copy()

# --- Orden de columnas “preferido” (solo se usarán las que existan) ---
preferidas = [
    "fecha","autor","tipo","valor","tags","tweet_origen","host","matched_target","categoria","registrable",
    # … añade aquí otras que suelas consultar primero:
    "brand","s_marca_mal","marca_detectada_mal","f_marca_mal","score_total","path_norm",
    "f_path_generica","f_dominio_barato","f_es_sin_marca","host_norm","host_path_norm"
]
cols_exist = [c for c in preferidas if c in df_lang_es.columns]
otras = [c for c in df_lang_es.columns if c not in cols_exist]
df_lang_es_view = df_lang_es[cols_exist + otras].copy()

print("Total URLs con pistas de idioma español:", len(df_lang_es_view))
display(df_lang_es_view)  # muestra TODAS las columnas disponibles en ese orden
# Out:
# Total URLs con pistas de idioma español: 1
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_25991/1452277657.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask_query = df_final["valor"].str.contains(LANG_ES_QUERY, na=False)
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_25991/1452277657.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask_path = df_final["path"].fillna("").str.contains(LANG_ES_PATH, na=False)
#                     fecha          autor tipo                        valor  \
# 1794  2025-06-14 14:26:04  CarlyGriggs13  url  https://dhl.com-esoo.top/es
#
#                  tags                                       tweet_origen  \
# 1794  #phishing #scam  https://x.com/CarlyGriggs13/status/19338937061...
#
#                   host matched_target categoria   registrable  ... f_es_tld  \
# 1794  dhl.com-esoo.top            DHL       NaN  com-esoo.top  ...    False
#
#       f_locale_es f_euro  f_plus34  s_kw_es f_kw_es  s_urgente  f_urgente  \
# 1794         True  False     False        0   False          0      False
#
#       s_idioma_extranjero f_idioma_extranjero
# 1794                    0               False
#
# [1 rows x 35 columns]

# %%
# === CELDA: Eliminar URL revisada con idioma español (DHL) ===

url_revisada = "https://dhl.com-esoo.top/es"

print("Antes de eliminar:", len(df_final))

df_final = df_final[~df_final["valor"].eq(url_revisada)].copy()

print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1409
# Después de eliminar: 1408

# %%
# === CELDA: Distribución de score_total en df_final ===

# Conteo de frecuencias de cada score_total
score_counts = df_final["score_total"].value_counts().sort_index()

print("Distribución de score_total (urls restantes):")
display(score_counts)

# También como histograma para visualizar mejor
import matplotlib.pyplot as plt

df_final["score_total"].hist(bins=20)
plt.xlabel("score_total")
plt.ylabel("Número de URLs")
plt.title("Distribución de score_total en df_final")
plt.show()
# Out:
# Distribución de score_total (urls restantes):
# score_total
# 2    1388
# 4      17
# 5       3
# Name: count, dtype: int64

# %%
# === CELDA: Filtrar URLs con score_total 4 o 5 ===

df_score45 = df_final[df_final["score_total"].isin([4,5])].copy()

print("Total con score_total 4 o 5:", len(df_score45))

# Vista con columnas útiles para el CSV unificado
df_vista_score45 = pd.DataFrame({
    "url": df_score45["valor"],
    "matched_target": df_score45["matched_target"].fillna(""),
    "fecha_hora_recoleccion": df_score45["fecha"],
    "fuente": "tweetfeed",
    "categoria": df_score45.get("categoria", ""),
    "notas": ""
})

display(df_vista_score45)
# Out:
# Total con score_total 4 o 5: 20
#                                                     url matched_target  \
# 96             https://kyberswap.campaigns-dashboard.co            HBO
# 279      http://au-en-dashboard.com/sign-in-stage-1.php            HBO
# 392           https://coinbase-pro-sign-in.company.site       Coinbase
# 616   http://s3-us-east-2.amazonaws.com/data-used-ph...         Amazon
# 623                          https://coinbase-signin.us       Coinbase
# 643                   https://coinbase-signinreview.com       Coinbase
# 718                         https://signups-monadvm.com            UPS
# 729                         https://signups-monadvm.net            UPS
# 969       https://webmail.verificarecapiti-coinbase.com       Coinbase
# 1083           https://coinbase-signin-page.paypalt.com         PayPal
# 1213    https://airbnbvacationinsurance.coinbase111.com         Airbnb
# 1432          https://dev.verificarecapiti-coinbase.com       Coinbase
# 1535  https://dhlhr.webauthor.com/modules/fx_dhl_esi...            DHL
# 1541      https://www.goudis.sbs/amazon=ap*signin000000         Amazon
# 1542      https://www.biousd.sbs/amazon=ap*signin000000         Amazon
# 1591     https://visa-intra.esoe8.com/pay-with-featured           Visa
# 1592  http://paypal-login.airsupplycompany.com/custo...         PayPal
# 1608  https://docusign.istatr.com/?_kx=hyad3df5gaii_...       DocuSign
# 1696     https://intranet.verificarecapiti-coinbase.com       Coinbase
# 2045          http://sites.google.com/view/docusign-uae       DocuSign
#
#      fecha_hora_recoleccion     fuente            categoria notas
# 96      2025-01-05 11:10:31  tweetfeed                  NaN
# 279     2025-01-26 05:10:08  tweetfeed                  NaN
# 392     2025-02-02 21:39:23  tweetfeed                  NaN
# 616     2025-02-12 19:24:55  tweetfeed  E-commerce / Retail
# 623     2025-02-12 21:56:16  tweetfeed                  NaN
# 643     2025-02-13 17:00:37  tweetfeed                  NaN
# 718     2025-02-19 21:24:58  tweetfeed                  NaN
# 729     2025-02-20 12:54:10  tweetfeed                  NaN
# 969     2025-03-10 09:29:27  tweetfeed                  NaN
# 1083    2025-03-18 19:45:35  tweetfeed          Pago Online
# 1213    2025-03-24 16:51:37  tweetfeed                  NaN
# 1432    2025-04-11 21:52:59  tweetfeed                  NaN
# 1535    2025-04-25 02:00:09  tweetfeed                  NaN
# 1541    2025-04-25 07:21:45  tweetfeed  E-commerce / Retail
# 1542    2025-04-25 07:22:33  tweetfeed  E-commerce / Retail
# 1591    2025-05-11 09:41:05  tweetfeed                  NaN
# 1592    2025-05-11 18:00:09  tweetfeed          Pago Online
# 1608    2025-05-18 10:00:04  tweetfeed                  NaN
# 1696    2025-06-06 22:18:51  tweetfeed                  NaN
# 2045    2025-07-16 19:36:32  tweetfeed                  NaN

# %%
# === CELDA: Eliminar URLs con score_total 4 o 5 (no sirven) ===

print("Antes de eliminar:", len(df_final))

df_final = df_final[~df_final["score_total"].isin([4,5])].copy()

print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1408
# Después de eliminar: 1388

# %%
# === CELDA: Filtrar URLs con registrable .es (incluye .com.es, .org.es, etc.) ===

df_es = df_final[df_final["registrable"].str.endswith(".es", na=False)].copy()

print("Total URLs con registrable .es:", len(df_es))

df_vista_es = pd.DataFrame({
    "url": df_es["valor"],
    "matched_target": df_es["matched_target"].fillna(""),
    "fecha_hora_recoleccion": df_es["fecha"],
    "fuente": "tweetfeed",
    "categoria": df_es.get("categoria", ""),
    "notas": ""
})

display(df_vista_es.head(20))
# Out:
# Total URLs con registrable .es: 0
# Empty DataFrame
# Columns: [url, matched_target, fecha_hora_recoleccion, fuente, categoria, notas]
# Index: []

# %%
# === CELDA: Filtrar por palabras clave españolas en path ===
import re

ES_KW = re.compile(
    r"(dni|dgt|correos|regularizaci[oó]n|multa|pago?s?|verificaci[oó]n|acceso|login|cliente?s?|seguridadsocial|agenciatributaria)",
    re.I
)

df_kw_es = df_final[df_final["path"].fillna("").str.contains(ES_KW)].copy()

print("Total URLs con palabras clave españolas en path:", len(df_kw_es))

df_vista_kw = pd.DataFrame({
    "url": df_kw_es["valor"],
    "matched_target": df_kw_es["matched_target"].fillna(""),
    "fecha_hora_recoleccion": df_kw_es["fecha"],
    "fuente": "tweetfeed",
    "categoria": df_kw_es.get("categoria", ""),
    "notas": "path_keyword"
})

display(df_vista_kw.head(38))
# Out:
# Total URLs con palabras clave españolas en path: 38
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_25991/2597092636.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_kw_es = df_final[df_final["path"].fillna("").str.contains(ES_KW)].copy()
#                                                     url matched_target  \
# 119             https://netflix-reglamentos.info/pages/        Netflix
# 120        https://ladizone.com/ei2ivfc2/facebook-login       Facebook
# 240        https://trademarkapartment.com/amazon-login/         Amazon
# 241        https://trademarkblackjack.com/amazon-login/         Amazon
# 242         https://trademarkistanbul.com/amazon-login/         Amazon
# 243         https://trademarklasvegas.com/amazon-login/         Amazon
# 244       https://tradepersonalinjury.com/amazon-login/         Amazon
# 366   https://lifecard-dealwise.dentexchange.net/Web...           Wise
# 678   https://orico-jurwise.haipengmi.com/eorico/login/           Wise
# 926            https://bodysmile-kyoto.com/amazon-login         Amazon
# 927         https://wakasaya-kaisendon.com/amazon-login         Amazon
# 928               https://sddq-trading.com/amazon-login         Amazon
# 957         https://goodideasicantuse.com/amazon-login/         Amazon
# 958          https://goodideasicantuse.com/amazon-login         Amazon
# 961   https://likeeverythingelse.com/amazon-login?an...         Amazon
# 965   https://bairunkitchenware.com/amazon-login?ans...         Amazon
# 966             https://xinyongwang365.com/amazon-login         Amazon
# 967                https://alexischall.com/amazon-login         Amazon
# 968                https://ytjiangsong.com/amazon-login         Amazon
# 982               https://fentishusong.com/amazon-login         Amazon
# 983   https://banksumedang.com/amazon-login?answer=2000         Amazon
# 984   https://banksumedang.com/amazon-login?answer=1994         Amazon
# 985   https://banksumedang.com/amazon-login?answer=2010         Amazon
# 1055                          https://spignel.com/login
# 1301  https://dhl-antholess.wzu01.com/portal_login_e...            DHL
# 1302  https://dhl-seekior.fsf47.com/portal_login_exp...            DHL
# 1336  https://firebasestorage.googleapis.com/v0/b/pr...
# 1379  https://www.americanexpress.com/account/login/...
# 1479              https://dashboard.hotbit.us.com/login            HBO
# 1497  https://auone-servewise.upb43.com/net/vwcnets/...           Wise
# 1540           https://americanexpress.zscrjt.com/login
# 1559  https://hostinghive.in/now/linkedIn.com/linked...       LinkedIn
# 1576  https://dhl-sheaire.pvgg4.com/portal_login_exp...            DHL
# 1612  https://store.steamchina.com/login/?redir=&red...          Steam
# 1636          https://whippedteen.com/amazon-login.html         Amazon
# 1957                  https://steamcomunmitty.com/login          Steam
# 2001  http://wezgol.click/css/webmail.aruba.it/user/...
# 2054   http://macrochipsperu.com/spotify/auth/login.php        Spotify
#
#      fecha_hora_recoleccion     fuente                    categoria  \
# 119     2025-01-07 04:23:29  tweetfeed  Streaming / Entretenimiento
# 120     2025-01-07 04:24:08  tweetfeed               Redes Sociales
# 240     2025-01-23 23:19:13  tweetfeed          E-commerce / Retail
# 241     2025-01-23 23:19:13  tweetfeed          E-commerce / Retail
# 242     2025-01-23 23:19:13  tweetfeed          E-commerce / Retail
# 243     2025-01-23 23:23:17  tweetfeed          E-commerce / Retail
# 244     2025-01-23 23:23:17  tweetfeed          E-commerce / Retail
# 366     2025-02-01 00:34:19  tweetfeed                          NaN
# 678     2025-02-15 08:15:23  tweetfeed                          NaN
# 926     2025-03-07 12:34:27  tweetfeed          E-commerce / Retail
# 927     2025-03-07 12:34:27  tweetfeed          E-commerce / Retail
# 928     2025-03-07 12:34:27  tweetfeed          E-commerce / Retail
# 957     2025-03-10 04:47:49  tweetfeed          E-commerce / Retail
# 958     2025-03-10 04:47:49  tweetfeed          E-commerce / Retail
# 961     2025-03-10 04:52:55  tweetfeed          E-commerce / Retail
# 965     2025-03-10 05:58:55  tweetfeed          E-commerce / Retail
# 966     2025-03-10 06:12:12  tweetfeed          E-commerce / Retail
# 967     2025-03-10 06:15:29  tweetfeed          E-commerce / Retail
# 968     2025-03-10 06:21:09  tweetfeed          E-commerce / Retail
# 982     2025-03-11 04:19:12  tweetfeed          E-commerce / Retail
# 983     2025-03-11 04:19:12  tweetfeed          E-commerce / Retail
# 984     2025-03-11 04:19:50  tweetfeed          E-commerce / Retail
# 985     2025-03-11 04:19:50  tweetfeed          E-commerce / Retail
# 1055    2025-03-18 02:31:45  tweetfeed                          NaN
# 1301    2025-03-29 23:14:25  tweetfeed                          NaN
# 1302    2025-03-29 23:14:25  tweetfeed                          NaN
# 1336    2025-04-03 04:46:38  tweetfeed                          NaN
# 1379    2025-04-07 03:08:05  tweetfeed                          NaN
# 1479    2025-04-15 03:46:43  tweetfeed                          NaN
# 1497    2025-04-19 02:41:02  tweetfeed                          NaN
# 1540    2025-04-25 06:52:45  tweetfeed                          NaN
# 1559    2025-05-05 18:00:06  tweetfeed                          NaN
# 1576    2025-05-07 15:53:00  tweetfeed                          NaN
# 1612    2025-05-19 14:29:21  tweetfeed                          NaN
# 1636    2025-06-01 23:17:59  tweetfeed          E-commerce / Retail
# 1957    2025-06-27 18:15:14  tweetfeed                          NaN
# 2001    2025-07-08 06:02:02  tweetfeed                          NaN
# 2054    2025-07-22 08:00:09  tweetfeed                          NaN
#
#              notas
# 119   path_keyword
# 120   path_keyword
# 240   path_keyword
# 241   path_keyword
# 242   path_keyword
# 243   path_keyword
# 244   path_keyword
# 366   path_keyword
# 678   path_keyword
# 926   path_keyword
# 927   path_keyword
# 928   path_keyword
# 957   path_keyword
# 958   path_keyword
# 961   path_keyword
# 965   path_keyword
# 966   path_keyword
# 967   path_keyword
# 968   path_keyword
# 982   path_keyword
# 983   path_keyword
# 984   path_keyword
# 985   path_keyword
# 1055  path_keyword
# 1301  path_keyword
# 1302  path_keyword
# 1336  path_keyword
# 1379  path_keyword
# 1479  path_keyword
# 1497  path_keyword
# 1540  path_keyword
# 1559  path_keyword
# 1576  path_keyword
# 1612  path_keyword
# 1636  path_keyword
# 1957  path_keyword
# 2001  path_keyword
# 2054  path_keyword

# %%
# === CELDA: Eliminar todas las URLs detectadas por palabras clave (ya revisadas) ===

print("Antes de eliminar:", len(df_final))

df_final = df_final[~df_final["valor"].isin(df_kw_es["valor"])].copy()

print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1388
# Después de eliminar: 1350

# %%
# === CELDA: Filtrar por palabras clave ES+EN en path ===
import re

KW_MIX = re.compile(
    r"(dni|dgt|correos|seguridadsocial|agenciatributaria|multa|regularizaci[oó]n|"
    r"pago?s?|verificaci[oó]n|acceso|login|cliente?s?|"
    r"secure|account|signin|sign-in|update|billing|password|credential|invoice)",
    re.I
)

df_kw_mix = df_final[df_final["path"].fillna("").str.contains(KW_MIX)].copy()

print("Total URLs con keywords ES+EN en path:", len(df_kw_mix))

df_vista_kw_mix = pd.DataFrame({
    "url": df_kw_mix["valor"],
    "matched_target": df_kw_mix["matched_target"].fillna(""),
    "fecha_hora_recoleccion": df_kw_mix["fecha"],
    "fuente": "tweetfeed",
    "categoria": df_kw_mix.get("categoria", ""),
    "notas": "path_keyword_mixed"
})

display(df_vista_kw_mix.head(28))
# Out:
# Total URLs con keywords ES+EN en path: 28
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_25991/1412177385.py:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_kw_mix = df_final[df_final["path"].fillna("").str.contains(KW_MIX)].copy()
#                                                     url matched_target  \
# 74    https://atoz-support.com/.bb-bb-hu/mkb/signin....
# 123   https://facebookconfirm.com/meta-team-pro/secu...       Facebook
# 133             https://www2.aeotikfdki.shop/ap/signin/
# 134              https://www2.aeotikfdki.shop/ap/signin
# 135               https://www2.yieutos2.shop/ap/signin/
# 136                https://www2.yieutos2.shop/ap/signin
# 280     http://au-auth-callback.com/sign-in-stage-1.php
# 574   https://fuckoffama.s3.ap-southeast-2.amazonaws...         Amazon
# 705   https://chasm.world/wp-content/themes/twentytw...
# 1253                  https://myjcb.dmjvpuio.xyz/signin
# 1318             https://amlweb-dev.amlbot.rocks/signin
# 1465            https://amazon.hiflyvanguard.com/update         Amazon
# 1466           https://amazon.hiflyvanguard.com/update/         Amazon
# 1467         https://amazon.123guitarlessons.com/update         Amazon
# 1509    https://wwwr2.dksbjc11.shop/ETGate=signin*16089
# 1530                   https://amazon.lhh123.top/update         Amazon
# 1607  https://cebuled.com/net/support/id-numb483/mya...
# 1627  https://www.printmydesign.store/boxjobo/secure...
# 1668                          https://gatebit.io/signin
# 1706  https://trading.web-globalinc.info/en/auth/sig...
# 1740  http://serveratsbc0auth.com/DXNEbwZqcG/control...
# 1798                      https://thefastbit.com/signin
# 1829             https://cheack.fusoscf.shop/ap/signin/
# 1944             https://exodusmenu.com/account/sign-in
# 1962                      https://c23zo81rx.com/sign-in
# 1963                     https://c23zo81rx.com/sign-in/
# 2046  https://buchmaierlaw.com/mail-biglobejp//sign-...
# 2056  https://id-ltunes-com.odljwjdsjnasdcs.today/si...
#
#      fecha_hora_recoleccion     fuente            categoria  \
# 74      2025-01-02 23:49:35  tweetfeed                  NaN
# 123     2025-01-07 05:32:35  tweetfeed       Redes Sociales
# 133     2025-01-08 05:17:12  tweetfeed                  NaN
# 134     2025-01-08 05:17:12  tweetfeed                  NaN
# 135     2025-01-08 05:18:20  tweetfeed                  NaN
# 136     2025-01-08 05:18:20  tweetfeed                  NaN
# 280     2025-01-26 05:10:08  tweetfeed                  NaN
# 574     2025-02-11 05:26:55  tweetfeed  E-commerce / Retail
# 705     2025-02-19 11:26:35  tweetfeed                  NaN
# 1253    2025-03-27 08:24:19  tweetfeed                  NaN
# 1318    2025-03-31 07:10:50  tweetfeed                  NaN
# 1465    2025-04-14 04:29:10  tweetfeed  E-commerce / Retail
# 1466    2025-04-14 04:29:10  tweetfeed  E-commerce / Retail
# 1467    2025-04-14 04:30:09  tweetfeed  E-commerce / Retail
# 1509    2025-04-20 04:36:40  tweetfeed                  NaN
# 1530    2025-04-22 05:51:57  tweetfeed  E-commerce / Retail
# 1607    2025-05-17 02:00:04  tweetfeed                  NaN
# 1627    2025-05-26 02:00:05  tweetfeed                  NaN
# 1668    2025-06-05 04:19:48  tweetfeed                  NaN
# 1706    2025-06-07 03:20:45  tweetfeed                  NaN
# 1740    2025-06-10 01:42:30  tweetfeed                  NaN
# 1798    2025-06-14 14:35:10  tweetfeed                  NaN
# 1829    2025-06-16 02:21:19  tweetfeed                  NaN
# 1944    2025-06-25 15:02:50  tweetfeed                  NaN
# 1962    2025-06-30 02:26:42  tweetfeed                  NaN
# 1963    2025-06-30 02:26:42  tweetfeed                  NaN
# 2046    2025-07-17 06:16:18  tweetfeed                  NaN
# 2056    2025-07-23 02:58:47  tweetfeed                  NaN
#
#                    notas
# 74    path_keyword_mixed
# 123   path_keyword_mixed
# 133   path_keyword_mixed
# 134   path_keyword_mixed
# 135   path_keyword_mixed
# 136   path_keyword_mixed
# 280   path_keyword_mixed
# 574   path_keyword_mixed
# 705   path_keyword_mixed
# 1253  path_keyword_mixed
# 1318  path_keyword_mixed
# 1465  path_keyword_mixed
# 1466  path_keyword_mixed
# 1467  path_keyword_mixed
# 1509  path_keyword_mixed
# 1530  path_keyword_mixed
# 1607  path_keyword_mixed
# 1627  path_keyword_mixed
# 1668  path_keyword_mixed
# 1706  path_keyword_mixed
# 1740  path_keyword_mixed
# 1798  path_keyword_mixed
# 1829  path_keyword_mixed
# 1944  path_keyword_mixed
# 1962  path_keyword_mixed
# 1963  path_keyword_mixed
# 2046  path_keyword_mixed
# 2056  path_keyword_mixed

# %%
# === CELDA: Eliminar URLs con keywords mixtas (no válidas) ===

print("Antes de eliminar:", len(df_final))

df_final = df_final[~df_final["valor"].isin(df_kw_mix["valor"])].copy()

print("Después de eliminar:", len(df_final))
# Out:
# Antes de eliminar: 1350
# Después de eliminar: 1322

# %%
# === CELDA: Crear patrón regex de variantes de marcas españolas (phishing) ===
# Lista directa del diccionario que pasaste
marcas_variante = [
    # Santander
    "santander", "santader", "sandander", "sntander", "s-antander", "santander-es", "santander-online",
    # BBVA
    "bbva", "bbav", "bbbaa", "bva", "bbvvaa", "bbva-online", "bbva-banca",
    # CaixaBank
    "caixabank", "caixabankk", "la-caixa", "caxabank", "kaixabank", "caixabank-online", "caixa-banca",
    # Sabadell
    "sabadell", "sabadell-online", "sabadll", "sabadelll", "sabadel", "sabadell-banco",
    # Movistar
    "movistar", "movistarr", "moviistar", "mvistar", "moviestar", "movistar-es", "movistar-cliente",
    # Telefónica
    "telefonica", "telefonika", "telefonica-es", "telefonicca", "telfonica", "telefoica",
    # Endesa
    "endesa", "endessa", "endesa-es", "ends", "enesa", "edesa",
    # Iberdrola
    "iberdrola", "iberdrola-es", "iberdro", "iberdrolaa", "iberdroia", "iberdrola-cliente",
    # El Corte Inglés
    "elcorteingles", "el-corte-ingles", "corteingles", "elcorteingless", "elcorteinglés", "el-corte-inglês",
    # Zara
    "zara", "zarazara", "zra", "zara-online", "zara-tienda", "zarashop",
    # Correos
    "correos", "correoss", "correeos", "coreros", "correos-es", "correos-online",
    # SEUR
    "seur", "seurr", "seur-es", "seur-express", "suer", "seur-envio",
    # Repsol
    "repsol", "repssol", "repsoll", "repsol-es", "repsol-online",
    # Renfe
    "renfe", "rrenfe", "renf", "renfe-online", "renfe-es", "renfe-ticket"
]

# Patrón regex robusto
VARIANTES_ES = re.compile(r"(" + "|".join(map(re.escape, marcas_variante)) + r")", re.I)

# %%
# === CELDA: Detectar URLs con variantes de marcas españolas ===

df_var_es = df_final[df_final["host_path_norm"].str.contains(VARIANTES_ES, na=False)].copy()

print("Total URLs con variantes de marcas españolas:", len(df_var_es))

df_vista_var_es = pd.DataFrame({
    "url": df_var_es["valor"],
    "matched_target": df_var_es["matched_target"].fillna(""),
    "fecha_hora_recoleccion": df_var_es["fecha"],
    "fuente": "tweetfeed",
    "categoria": df_var_es.get("categoria", ""),
    "notas": "marca_es_variante"
})

display(df_vista_var_es.head(20))
# Out:
# Total URLs con variantes de marcas españolas: 0
# /var/folders/fc/53j7mrrs40j5jvl09zqzrcqw0000gn/T/ipykernel_25991/1357203117.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_var_es = df_final[df_final["host_path_norm"].str.contains(VARIANTES_ES, na=False)].copy()
# Empty DataFrame
# Columns: [url, matched_target, fecha_hora_recoleccion, fuente, categoria, notas]
# Index: []

# %%
# === CELDA: Guardar URLs filtradas por score pero no targeting español ===
from pathlib import Path

out_path = Path("../../../data/processed/phishing/filtrado_1_tf_no.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)

df_final.to_csv(out_path, index=False)
print("Guardadas", len(df_final), "URLs descartadas en:", out_path)
# Out:
# Guardadas 1322 URLs descartadas en: ../../../data/processed/phishing/filtrado_1_tf_no.csv
